# %%
# %load_ext autoreload
# %autoreload 2

from iqm.benchmarks.optimization.qscore import *
import random

# %% [markdown]
# # Choose (or define) a backend

# %%
backend = "fakeadonis"
#backend = "fakeapollo"
#backend = "garnet"
#backend = "deneb"

# %% [markdown]
# #### Set IQM Token if using Resonance.

# %%
# import os
# os.environ["IQM_TOKEN"] = "XXXXXXXXXXXXXX"

# %% [markdown]
# # Qscore Configuration

# %%
EXAMPLE_QSCORE = QScoreConfiguration(
    num_instances = 100,
    num_qaoa_layers= 1,
    shots = 20_000,
    calset_id=None, # calibration set ID, default is None
    min_num_nodes =  2,
    max_num_nodes = 5,
    use_virtual_node = True,
    use_classically_optimized_angles = True,
    choose_qubits_routine = "custom",
    custom_qubits_array=[
                    [2, 0],
                    [2, 0, 1],
                    [2, 0, 1, 3],
                    [2, 0, 1, 3, 4]],
    seed = random.randint(1, 999999),
    )

# %% [markdown]
# # Run the experiment

# %%
benchmark_qscore = QScoreBenchmark(backend, EXAMPLE_QSCORE)
run0_qscore = benchmark_qscore.run()

# %% [markdown]
# # Perform Analysis

# %%
result0_qscore = benchmark_qscore.analyze()
# Out:
# 2024-12-23 10:46:38,325 - iqm.benchmarks.logging_config - INFO - Q-Score = 2 passed with approximation ratio (Beta) 0.4171; Avg MaxCut size: 0.4600
# 2024-12-23 10:46:39,861 - iqm.benchmarks.logging_config - INFO - Q-Score = 3 passed with approximation ratio (Beta) 0.5461; Avg MaxCut size: 1.2551
# 2024-12-23 10:46:41,981 - iqm.benchmarks.logging_config - INFO - Q-Score = 4 passed with approximation ratio (Beta) 0.3619; Avg MaxCut size: 2.0153
# 2024-12-23 10:46:45,048 - iqm.benchmarks.logging_config - INFO - Q-Score = 5 failed with approximation ratio (Beta) 0.1981 < 0.2; Avg MaxCut size: 2.8943

# %%
result0_qscore.observations
# Out:
# [BenchmarkObservation(name='approximation_ratio', value=0.4171135506999298, identifier=BenchmarkObservationIdentifier(qubit_indices=2), uncertainty=0.09949315494779445),
#  BenchmarkObservation(name='is_succesful', value='True', identifier=BenchmarkObservationIdentifier(qubit_indices=2), uncertainty=None),
#  BenchmarkObservation(name='Qscore_result', value=2, identifier=BenchmarkObservationIdentifier(qubit_indices=2), uncertainty=None),
#  BenchmarkObservation(name='approximation_ratio', value=0.5460965908535499, identifier=BenchmarkObservationIdentifier(qubit_indices=3), uncertainty=0.0739005543806993),
#  BenchmarkObservation(name='is_succesful', value='True', identifier=BenchmarkObservationIdentifier(qubit_indices=3), uncertainty=None),
#  BenchmarkObservation(name='Qscore_result', value=3, identifier=BenchmarkObservationIdentifier(qubit_indices=3), uncertainty=None),
#  BenchmarkObservation(name='approximation_ratio', value=0.3618992275280895, identifier=BenchmarkObservationIdentifier(qubit_indices=4), uncertainty=0.04507087623702991),
#  BenchmarkObservation(name='is_succesful', value='True', identifier=BenchmarkObservationIdentifier(qubit_indices=4), uncertainty=None),
#  BenchmarkObservation(name='Qscore_result', value=4, identifier=BenchmarkObservationIdentifier(qubit_indices=4), uncertainty=None),
#  BenchmarkObservation(name='approximation_ratio', value=0.19811135166540042, identifier=BenchmarkObservationIdentifier(qubit_indices=5), uncertainty=0.037048839601983796),
#  BenchmarkObservation(name='is_succesful', value='False', identifier=BenchmarkObservationIdentifier(qubit_indices=5), uncertainty=None),
#  BenchmarkObservation(name='Qscore_result', value=1, identifier=BenchmarkObservationIdentifier(qubit_indices=5), uncertainty=None)]

# %%
result0_qscore.plot_all()
