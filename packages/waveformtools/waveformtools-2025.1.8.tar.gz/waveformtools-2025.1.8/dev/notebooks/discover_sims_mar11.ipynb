# %%
import numpy as np
import os
from pathlib import Path
import config
# Out:
# Failed to start the Kernel.
#
# '_xsrf' argument missing from POST.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
if config.print_verbosity < 3:
    from config.verbosity import levels

    vl = levels()
    vl.set_print_verbosity(2)

# %%
exec(open("/mnt/pfs/vaishak.p/soft/modules-5.2.0/init/python.py").read())
module("list")
module("unload", "gcc/11.1.0")
module("load", "gcc/11.1.0")
# Out:
# Currently Loaded Modulefiles:
#  1) use.own             5) gsl/2.7.1            9) make/make-4.4
#  2) gcc/11.1.0          6) lapack/3.11.0       10) papi/7.0.0
#  3) gcc/openmpi/4.1.4   7) hdf5/1.14.0-serial
#  4) fftw/3.3.10         8) petsc/3.18.4-nh5
# True

# %%
from waveformtools.sxs.discover_sims import SimulationExplorer
# Out:
# /mnt/pfs/vaishak.p/Projects/Codes/custom_libraries/waveformtools/waveformtools
# No module named 'pycbc'

# %%
list_of_search_dirs = [
    "/mnt/pfs/vaishak.p/sims/SpEC/gcc/bfi/ICTSEccParallel",
    "/mnt/pfs/vaishak.p/sims/SpEC/gcc/bfi/EccContPrecDiff",
    "/mnt/pfs/vaishak.p/sims/SpEC/gcc/bfi/EccPrecDiff",
    "/mnt/pfs/vaishak.p/sims/SpEC/gcc",
]

# %%
se = SimulationExplorer(
    search_dir=list_of_search_dirs[0],
    bfi_home_dir="/mnt/pfs/vaishak.p/sims/SpEC/BFI/BFI",
    bfi_project_name="ICTSEccParallel",
    prepared_waveforms_dir="/mnt/pfs/vaishak.p/Projects/Codes/waveforms",
)

# %%
se = SimulationExplorer(
    search_dir=list_of_search_dirs[1],
    bfi_home_dir="/mnt/pfs/vaishak.p/sims/SpEC/BFI/BFI",
    bfi_project_name="EccContPrecDiff",
    prepared_waveforms_dir="/mnt/pfs/vaishak.p/Projects/Codes/waveforms",
)

# %%
se = SimulationExplorer(
    search_dir=list_of_search_dirs[2],
    bfi_home_dir="/mnt/pfs/vaishak.p/sims/SpEC/BFI/BFI",
    bfi_project_name="EccPrecDiff",
    prepared_waveforms_dir="/mnt/pfs/vaishak.p/Projects/Codes/waveforms",
)

# %%
se.search_simulations()
# Out:
# Searching in /mnt/pfs/vaishak.p/sims/SpEC/gcc/bfi/EccContPrecDiff
# All subdirs ['EccContPrecDiff008', 'EccContPrecDiff005', 'EccContPrecDiff003', 'EccContPrecDiff006', 'EccContPrecDiff002', 'EccContPrecDiff007', 'EccContPrecDiff004', 'EccContPrecDiff001', 'summary.pdf']
# 	Searching in /mnt/pfs/vaishak.p/sims/SpEC/gcc/bfi/EccContPrecDiff/EccContPrecDiff008
# Checking /mnt/pfs/vaishak.p/sims/SpEC/gcc/bfi/EccContPrecDiff/EccContPrecDiff008
# 	 /mnt/pfs/vaishak.p/sims/SpEC/gcc/bfi/EccContPrecDiff/EccContPrecDiff008 is a simulation directory
# 	Searching in /mnt/pfs/vaishak.p/sims/SpEC/gcc/bfi/EccContPrecDiff/EccContPrecDiff005
# Checking /mnt/pfs/vaishak.p/sims/SpEC/gcc/bfi/EccContPrecDiff/EccContPrecDiff005
# 	 /mnt/pfs/vaishak.p/sims/SpEC/gcc/bfi/EccContPrecDiff/EccContPrecDiff005 is a simulation directory
# 	Searching in /mnt/pfs/vaishak.p/sims/SpEC/gcc/bfi/EccContPrecDiff/EccContPrecDiff003
# Checking /mnt/pfs/vaishak.p/sims/SpEC/gcc/bfi/EccContPrecDiff/EccContPrecDiff003
# 	 /mnt/pfs/vaishak.p/sims/SpEC/gcc/bfi/EccContPrecDiff/EccContPrecDiff003 is a simulation directory
# 	Searching in /mnt/pfs/vaishak.p/sims/SpEC/gcc/bfi/EccContPrecDiff/EccContPrecDiff006
# Checking /mnt/pfs/vaishak.p/sims/SpEC/gcc/bfi/EccContPrecDiff/EccContPrecDiff006
# 	 /mnt/pfs/vaishak.p/sims/SpEC/gcc/bfi/EccContPrecDiff/EccContPrecDiff006 is a simulation directory
# 	Searching in /mnt/pfs/vaishak.p/sims/SpEC/gcc/bfi/EccContPrecDiff/EccContPrecDiff002
# Checking /mnt/pfs/vaishak.p/sims/SpEC/gcc/bfi/EccContPrecDiff/EccContPrecDiff002
# 	 /mnt/pfs/vaishak.p/sims/SpEC/gcc/bfi/EccContPrecDiff/EccContPrecDiff002 is a simulation directory
# 	Searching in /mnt/pfs/vaishak.p/sims/SpEC/gcc/bfi/EccContPrecDiff/EccContPrecDiff007
# Checking /mnt/pfs/vaishak.p/sims/SpEC/gcc/bfi/EccContPrecDiff/EccContPrecDiff007
# 	 /mnt/pfs/vaishak.p/sims/SpEC/gcc/bfi/EccContPrecDiff/EccContPrecDiff007 is a simulation directory
# 	Searching in /mnt/pfs/vaishak.p/sims/SpEC/gcc/bfi/EccContPrecDiff/EccContPrecDiff004
# Checking /mnt/pfs/vaishak.p/sims/SpEC/gcc/bfi/EccContPrecDiff/EccContPrecDiff004
# 	 /mnt/pfs/vaishak.p/sims/SpEC/gcc/bfi/EccContPrecDiff/EccContPrecDiff004 is a simulation directory
# 	Searching in /mnt/pfs/vaishak.p/sims/SpEC/gcc/bfi/EccContPrecDiff/EccContPrecDiff001
# Checking /mnt/pfs/vaishak.p/sims/SpEC/gcc/bfi/EccContPrecDiff/EccContPrecDiff001
# 	 /mnt/pfs/vaishak.p/sims/SpEC/gcc/bfi/EccContPrecDiff/EccContPrecDiff001 is a simulation directory
# 	Searching in /mnt/pfs/vaishak.p/sims/SpEC/gcc/bfi/EccContPrecDiff/summary.pdf
# Checking /mnt/pfs/vaishak.p/sims/SpEC/gcc/bfi/EccContPrecDiff/summary.pdf
# /mnt/pfs/vaishak.p/sims/SpEC/gcc/bfi/EccContPrecDiff/summary.pdf is not a directory

# %%
se.available_sim_names
# Out:
# ['EccContPrecDiff008',
#  'EccContPrecDiff005',
#  'EccContPrecDiff003',
#  'EccContPrecDiff006',
#  'EccContPrecDiff002',
#  'EccContPrecDiff007',
#  'EccContPrecDiff004',
#  'EccContPrecDiff001']

# %%
se.fetch_sim_params()
# Out:
# Parsing simulation parameters.input file for /mnt/pfs/vaishak.p/sims/SpEC/gcc/bfi/EccContPrecDiff/EccContPrecDiff008/Ecc0/Params.input
# Parsing simulation parameters.input file for /mnt/pfs/vaishak.p/sims/SpEC/gcc/bfi/EccContPrecDiff/EccContPrecDiff005/Ecc0/Params.input
# Parsing simulation parameters.input file for /mnt/pfs/vaishak.p/sims/SpEC/gcc/bfi/EccContPrecDiff/EccContPrecDiff003/Ecc0/Params.input
# Parsing simulation parameters.input file for /mnt/pfs/vaishak.p/sims/SpEC/gcc/bfi/EccContPrecDiff/EccContPrecDiff006/Ecc0/Params.input
# Parsing simulation parameters.input file for /mnt/pfs/vaishak.p/sims/SpEC/gcc/bfi/EccContPrecDiff/EccContPrecDiff002/Ecc0/Params.input
# Parsing simulation parameters.input file for /mnt/pfs/vaishak.p/sims/SpEC/gcc/bfi/EccContPrecDiff/EccContPrecDiff007/Ecc0/Params.input
# Parsing simulation parameters.input file for /mnt/pfs/vaishak.p/sims/SpEC/gcc/bfi/EccContPrecDiff/EccContPrecDiff004/Ecc0/Params.input
# Parsing simulation parameters.input file for /mnt/pfs/vaishak.p/sims/SpEC/gcc/bfi/EccContPrecDiff/EccContPrecDiff001/Ecc0/Params.input
# fresults ['RunID=001', 'ZwickyDays=0', 'SemiMajorAxis=21', 'Eccentricity=0.04', 'AnomalyAngle=0.4', 'ReferenceTime=0']
# fresults ['RunID=002', 'ZwickyDays=0', 'SemiMajorAxis=24', 'Eccentricity=0.08', 'AnomalyAngle=1.5', 'ReferenceTime=0']
# fresults ['RunID=003', 'ZwickyDays=0', 'SemiMajorAxis=11', 'Eccentricity=0.1', 'AnomalyAngle=0', 'ReferenceTime=0']
# fresults ['RunID=004', 'ZwickyDays=0', 'SemiMajorAxis=11', 'Eccentricity=0.15', 'AnomalyAngle=0', 'ReferenceTime=0']
# fresults ['RunID=005', 'ZwickyDays=0', 'SemiMajorAxis=11', 'Eccentricity=0.18', 'AnomalyAngle=0', 'ReferenceTime=0']
# fresults ['RunID=006', 'ZwickyDays=0', 'SemiMajorAxis=11', 'Eccentricity=0.21', 'AnomalyAngle=1', 'ReferenceTime=0']
# fresults ['RunID=007', 'ZwickyDays=0', 'SemiMajorAxis=14', 'Eccentricity=0.08', 'AnomalyAngle=1.5', 'ReferenceTime=0']
# fresults ['RunID=008', 'ZwickyDays=0', 'SemiMajorAxis=17', 'Eccentricity=0.18', 'AnomalyAngle=0', 'ReferenceTime=0']
# Loading segments in EccContPrecDiff008
# Available dirs ['ApparentHorizonFinders.input', 'PBandJ_StartJob.sh', 'EvolutionRingdown.input', 'GrSetupAndEvolutionRingdown.input', 'GrObservers.input', 'RefinementOptionHistory.input', 'Lev2_AL', 'Lev2_AN', 'Lev3_AL', 'DoMultipleRunsRingdown.input', 'GrStateChangers.input', 'Lev3_AG', 'Lev2_AE', 'Lev3_AE', 'Lev3_AI', 'Lev2_AB', 'Lev2_AJ', 'Evolution.input', 'Lev3_AD', 'Lev3_AA', 'Lev3_AP', 'Lev3_AB', 'Lev2_AH', 'Lev2_AA', 'GrInitialConditions.input', 'GrDomain.input', 'Lev2_Ringdown', 'Lev2_AM', 'Lev3_AJ', 'AmrDriverRingdown.input', 'Lev3_Ringdown', 'Lev3_AK', 'StartJob.sh', 'GrDataBoxItemsRingdown.input', 'CombinedObservers.input', 'AmrDriver.input', 'Lev3_AH', 'CombinedStateChangers.input', 'Lev2_AC', 'GrVolumeDumps.input', 'Lev2_AF', 'bin', 'ApparentHorizonFindersRingdown.input', 'Lev3_AN', 'GrInitialConditionsRingdown.input', 'Lev3_AC', 'AmrTolerancesRingdown.input', 'GaugeItems.input', 'GrObserversRingdown.input', 'SpEC', 'Lev3_AM', 'AmrTolerances.input', 'Lev2_AG', 'Lev3_AF', 'SpatialCoordMap.input', 'ConstraintDampingRingdown.input', 'Lev2_AK', 'Lev3_AO', 'GrObservers.input.new', 'Lev2_AI', 'GrDataBoxItems.input', 'GrWaveExtraction.input', 'DoMultipleRuns.input', 'ProhibitStartJobReruns.txt', 'GrSetupAndEvolution.input', 'ConstraintDamping.input', 'GrBoundaryConditions.input', 'Lev2_AD']
# Available lev dirs ['Lev2_AL', 'Lev2_AN', 'Lev3_AL', 'Lev3_AG', 'Lev2_AE', 'Lev3_AE', 'Lev3_AI', 'Lev2_AB', 'Lev2_AJ', 'Lev3_AD', 'Lev3_AA', 'Lev3_AP', 'Lev3_AB', 'Lev2_AH', 'Lev2_AA', 'Lev2_AM', 'Lev3_AJ', 'Lev3_AK', 'Lev3_AH', 'Lev2_AC', 'Lev2_AF', 'Lev3_AN', 'Lev3_AC', 'Lev3_AM', 'Lev2_AG', 'Lev3_AF', 'Lev2_AK', 'Lev3_AO', 'Lev2_AI', 'Lev2_AD']
# Available ringdown lev dirs ['Lev2_Ringdown', 'Lev3_Ringdown']
# Available levs {2, 3}
# Available ringdown levs {2, 3}
# Loading segments in EccContPrecDiff005
# Available dirs ['AmrDriver.input', 'bin', 'Lev2_AF', 'SpEC', 'GrVolumeDumps.input', 'ProhibitStartJobReruns.txt', 'Evolution.input', 'Lev3_AC', 'Lev3_AM', 'Lev2_AD', 'AmrTolerancesRingdown.input', 'Lev2_AM', 'Lev3_AE', 'AmrDriverRingdown.input', 'Lev2_Ringdown', 'Lev3_AF', 'EvolutionRingdown.input', 'CombinedStateChangers.input', 'Lev2_AB', 'ApparentHorizonFinders.input', 'GrDataBoxItems.input', 'Lev2_AI', 'GrBoundaryConditions.input', 'Lev2_AL', 'Lev3_AK', 'GrSetupAndEvolutionRingdown.input', 'Lev2_AH', 'Lev3_AD', 'Lev3_AH', 'Lev3_AJ', 'Lev2_AK', 'Lev3_AB', 'PBandJ_StartJob.sh', 'SpatialCoordMap.input', 'ConstraintDampingRingdown.input', 'GrObserversRingdown.input', 'Lev2_AJ', 'GrObservers.input.new', 'CombinedObservers.input', 'GrDomain.input', 'Lev3_AA', 'StartJob.sh', 'GrInitialConditions.input', 'Lev2_AA', 'Lev2_AC', 'GrInitialConditionsRingdown.input', 'RefinementOptionHistory.input', 'GaugeItems.input', 'Lev2_AG', 'Lev2_AE', 'Lev3_AL', 'GrObservers.input', 'Lev3_AG', 'GrStateChangers.input', 'AmrTolerances.input', 'GrDataBoxItemsRingdown.input', 'Lev3_Ringdown', 'ConstraintDamping.input', 'GrWaveExtraction.input', 'ApparentHorizonFindersRingdown.input', 'DoMultipleRunsRingdown.input', 'Lev3_AI', 'GrSetupAndEvolution.input', 'DoMultipleRuns.input']
# Available lev dirs ['Lev2_AF', 'Lev3_AC', 'Lev3_AM', 'Lev2_AD', 'Lev2_AM', 'Lev3_AE', 'Lev3_AF', 'Lev2_AB', 'Lev2_AI', 'Lev2_AL', 'Lev3_AK', 'Lev2_AH', 'Lev3_AD', 'Lev3_AH', 'Lev3_AJ', 'Lev2_AK', 'Lev3_AB', 'Lev2_AJ', 'Lev3_AA', 'Lev2_AA', 'Lev2_AC', 'Lev2_AG', 'Lev2_AE', 'Lev3_AL', 'Lev3_AG', 'Lev3_AI']
# Available ringdown lev dirs ['Lev2_Ringdown', 'Lev3_Ringdown']
# Available levs {2, 3}
# Available ringdown levs {2, 3}
# Loading segments in EccContPrecDiff003
# Available dirs ['ApparentHorizonFinders.input', 'Lev2_AZ', 'PBandJ_StartJob.sh', 'Lev2_AQ', 'EvolutionRingdown.input', 'Lev2_AR', 'GrSetupAndEvolutionRingdown.input', 'GrObservers.input', 'RefinementOptionHistory.input', 'Lev2_AL', 'Lev3_AV', 'Lev2_AN', 'Lev3_AL', 'DoMultipleRunsRingdown.input', 'GrStateChangers.input', 'Lev3_AG', 'joinedEccContPrec003Lev2.h5', 'Lev3_AX', 'Lev2_AS', 'Lev2_AE', 'Lev3_AE', 'Lev3_AI', 'Lev2_AB', 'Lev2_AJ', 'Lev2_AY', 'Evolution.input', 'Lev3_AD', 'Lev3_AA', 'Lev3_AP', 'Lev3_AS', 'Lev3_AB', 'Lev2_AH', 'Lev2_AA', 'GrInitialConditions.input', 'GrDomain.input', 'Lev3_AU', 'Lev2_Ringdown', 'Lev2_AM', 'Lev3_AW', 'Lev3_AJ', 'AmrDriverRingdown.input', 'Lev3_Ringdown', 'Lev3_AK', 'StartJob.sh', 'Lev2_AO', 'GrDataBoxItemsRingdown.input', 'CombinedObservers.input', 'AmrDriver.input', 'Lev2_BA', 'joined.h5', 'Lev3_AQ', 'Lev3_AH', 'CombinedStateChangers.input', 'Lev2_AC', 'GrVolumeDumps.input', 'Lev2_AF', 'bin', 'ApparentHorizonFindersRingdown.input', 'Lev3_AN', 'Lev2_AW', 'GrInitialConditionsRingdown.input', 'Lev3_AC', 'Lev2_AP', 'AmrTolerancesRingdown.input', 'GaugeItems.input', 'GrObserversRingdown.input', 'SpEC', 'Lev3_AM', 'AmrTolerances.input', 'Lev2_AG', 'Lev3_AR', 'Errors000.txt', 'Lev2_AU', 'Lev3_AF', 'SpatialCoordMap.input', 'ConstraintDampingRingdown.input', 'Lev2_AK', 'Lev3_AO', 'Lev3_AY', 'GrObservers.input.new', 'Lev2_AI', 'Lev3_AZ', 'Lev2_AX', 'GrDataBoxItems.input', 'GrWaveExtraction.input', 'DoMultipleRuns.input', 'Lev3_AT', 'ProhibitStartJobReruns.txt', 'GrSetupAndEvolution.input', 'Lev2_AV', 'Lev2_AT', 'ConstraintDamping.input', 'GrBoundaryConditions.input', 'Lev2_AD']
# Available lev dirs ['Lev2_AZ', 'Lev2_AQ', 'Lev2_AR', 'Lev2_AL', 'Lev3_AV', 'Lev2_AN', 'Lev3_AL', 'Lev3_AG', 'Lev3_AX', 'Lev2_AS', 'Lev2_AE', 'Lev3_AE', 'Lev3_AI', 'Lev2_AB', 'Lev2_AJ', 'Lev2_AY', 'Lev3_AD', 'Lev3_AA', 'Lev3_AP', 'Lev3_AS', 'Lev3_AB', 'Lev2_AH', 'Lev2_AA', 'Lev3_AU', 'Lev2_AM', 'Lev3_AW', 'Lev3_AJ', 'Lev3_AK', 'Lev2_AO', 'Lev2_BA', 'Lev3_AQ', 'Lev3_AH', 'Lev2_AC', 'Lev2_AF', 'Lev3_AN', 'Lev2_AW', 'Lev3_AC', 'Lev2_AP', 'Lev3_AM', 'Lev2_AG', 'Lev3_AR', 'Lev2_AU', 'Lev3_AF', 'Lev2_AK', 'Lev3_AO', 'Lev3_AY', 'Lev2_AI', 'Lev3_AZ', 'Lev2_AX', 'Lev3_AT', 'Lev2_AV', 'Lev2_AT', 'Lev2_AD']
# Available ringdown lev dirs ['Lev2_Ringdown', 'Lev3_Ringdown']
# Available levs {2, 3}
# Available ringdown levs {2, 3}
# Loading segments in EccContPrecDiff006
# Available dirs ['AmrDriver.input', 'Lev2_AP', 'bin', 'Lev2_AF', 'SpEC', 'GrVolumeDumps.input', 'Lev3_AR', 'Lev3_AO', 'ProhibitStartJobReruns.txt', 'Evolution.input', 'Lev3_AC', 'Lev3_AM', 'Lev2_AD', 'Lev3_AP', 'Lev3_AQ', 'AmrTolerancesRingdown.input', 'Lev2_AM', 'Lev3_AE', 'AmrDriverRingdown.input', 'Lev2_Ringdown', 'Lev3_AF', 'EvolutionRingdown.input', 'CombinedStateChangers.input', 'Lev2_AB', 'Lev2_AO', 'ApparentHorizonFinders.input', 'GrDataBoxItems.input', 'Lev2_AI', 'GrBoundaryConditions.input', 'Lev2_AL', 'Lev3_AK', 'GrSetupAndEvolutionRingdown.input', 'Lev2_AH', 'Lev3_AD', 'Lev3_AH', 'Lev3_AJ', 'Lev2_AK', 'Lev3_AB', 'PBandJ_StartJob.sh', 'SpatialCoordMap.input', 'ConstraintDampingRingdown.input', 'GrObserversRingdown.input', 'Lev2_AJ', 'GrObservers.input.new', 'CombinedObservers.input', 'GrDomain.input', 'Lev3_AA', 'StartJob.sh', 'GrInitialConditions.input', 'Lev2_AN', 'Lev2_AA', 'Lev2_AC', 'GrInitialConditionsRingdown.input', 'RefinementOptionHistory.input', 'GaugeItems.input', 'Lev2_AG', 'Lev2_AE', 'Lev3_AL', 'Lev2_AQ', 'GrObservers.input', 'Lev3_AG', 'GrStateChangers.input', 'Lev3_AN', 'AmrTolerances.input', 'GrDataBoxItemsRingdown.input', 'Lev3_Ringdown', 'ConstraintDamping.input', 'GrWaveExtraction.input', 'ApparentHorizonFindersRingdown.input', 'DoMultipleRunsRingdown.input', 'Lev3_AI', 'GrSetupAndEvolution.input', 'DoMultipleRuns.input']
# Available lev dirs ['Lev2_AP', 'Lev2_AF', 'Lev3_AR', 'Lev3_AO', 'Lev3_AC', 'Lev3_AM', 'Lev2_AD', 'Lev3_AP', 'Lev3_AQ', 'Lev2_AM', 'Lev3_AE', 'Lev3_AF', 'Lev2_AB', 'Lev2_AO', 'Lev2_AI', 'Lev2_AL', 'Lev3_AK', 'Lev2_AH', 'Lev3_AD', 'Lev3_AH', 'Lev3_AJ', 'Lev2_AK', 'Lev3_AB', 'Lev2_AJ', 'Lev3_AA', 'Lev2_AN', 'Lev2_AA', 'Lev2_AC', 'Lev2_AG', 'Lev2_AE', 'Lev3_AL', 'Lev2_AQ', 'Lev3_AG', 'Lev3_AN', 'Lev3_AI']
# Available ringdown lev dirs ['Lev2_Ringdown', 'Lev3_Ringdown']
# Available levs {2, 3}
# Available ringdown levs {2, 3}
# Loading segments in EccContPrecDiff002
# Available dirs ['GrInitialConditions.input', 'Lev3_AQ', 'AmrTolerances.input', 'Lev4_AM', 'CombinedObservers.input', 'Lev3_AS', 'Lev3_AN', 'Lev4_AC', 'Lev4_AA', 'Lev4_AB', 'GrBoundaryConditions.input', 'Lev3_AE', 'Lev3_AD', 'GrObservers.input', 'Lev3_AP', 'GrSetupAndEvolutionRingdown.input', 'ApparentHorizonFindersRingdown.input', 'AmrDriverRingdown.input', 'Evolution.input', 'SpatialCoordMap.input', 'Lev4_AG', 'ProhibitStartJobReruns.txt', 'GrDataBoxItemsRingdown.input', 'Lev4_AE', 'Lev3_AJ', 'Lev4_AI', 'GrInitialConditionsRingdown.input', 'PBandJ_StartJob.sh', 'Lev3_AL', 'SpEC', 'GrObservers.input.new', 'Lev4_AH', 'DoMultipleRunsRingdown.input', 'Lev4_AD', 'Lev3_AF', 'GrDataBoxItems.input', 'GrSetupAndEvolution.input', 'GrDomain.input', 'ConstraintDamping.input', 'AmrTolerancesRingdown.input', 'RefinementOptionHistory.input', 'DoMultipleRuns.input', 'Lev4_AL', 'AmrDriver.input', 'Lev3_AK', 'Lev4_AJ', 'Lev3_AO', 'CombinedStateChangers.input', 'Lev4_AK', 'Lev3_AA', 'GrWaveExtraction.input', 'Lev3_AC', 'Lev3_AR', 'ConstraintDampingRingdown.input', 'Lev4_AF', 'Lev3_AH', 'Lev3_AB', 'Lev3_AM', 'StartJob.sh', 'GrObserversRingdown.input', 'Lev4_AN', 'GrVolumeDumps.input', 'Lev3_AI', 'ApparentHorizonFinders.input', 'bin', 'EvolutionRingdown.input', 'GrStateChangers.input', 'Lev3_AG', 'GaugeItems.input', 'Lev3_AT']
# Available lev dirs ['Lev3_AQ', 'Lev4_AM', 'Lev3_AS', 'Lev3_AN', 'Lev4_AC', 'Lev4_AA', 'Lev4_AB', 'Lev3_AE', 'Lev3_AD', 'Lev3_AP', 'Lev4_AG', 'Lev4_AE', 'Lev3_AJ', 'Lev4_AI', 'Lev3_AL', 'Lev4_AH', 'Lev4_AD', 'Lev3_AF', 'Lev4_AL', 'Lev3_AK', 'Lev4_AJ', 'Lev3_AO', 'Lev4_AK', 'Lev3_AA', 'Lev3_AC', 'Lev3_AR', 'Lev4_AF', 'Lev3_AH', 'Lev3_AB', 'Lev3_AM', 'Lev4_AN', 'Lev3_AI', 'Lev3_AG', 'Lev3_AT']
# Available ringdown lev dirs []
# Available levs {3, 4}
# Available ringdown levs set()
# Loading segments in EccContPrecDiff007
# Available dirs ['AmrDriver.input', 'Lev2_AP', 'bin', 'Lev2_AF', 'SpEC', 'GrVolumeDumps.input', 'Lev3_AR', 'Lev3_AO', 'ProhibitStartJobReruns.txt', 'Evolution.input', 'Lev3_AC', 'Lev3_AM', 'Lev2_AD', 'Lev3_AP', 'Lev3_AQ', 'AmrTolerancesRingdown.input', 'Lev2_AM', 'Lev3_AE', 'AmrDriverRingdown.input', 'Lev2_Ringdown', 'Lev3_AF', 'EvolutionRingdown.input', 'CombinedStateChangers.input', 'Lev2_AB', 'Lev2_AO', 'ApparentHorizonFinders.input', 'Lev3_AU', 'GrDataBoxItems.input', 'Lev2_AI', 'GrBoundaryConditions.input', 'Lev2_AL', 'Lev3_AK', 'GrSetupAndEvolutionRingdown.input', 'Lev2_AH', 'Lev3_AV', 'Lev2_AR', 'Lev3_AD', 'Lev3_AH', 'Lev3_AJ', 'Lev2_AK', 'Lev3_AB', 'PBandJ_StartJob.sh', 'SpatialCoordMap.input', 'ConstraintDampingRingdown.input', 'GrObserversRingdown.input', 'Lev2_AJ', 'Lev2_AS', 'GrObservers.input.new', 'CombinedObservers.input', 'GrDomain.input', 'Lev3_AA', 'StartJob.sh', 'GrInitialConditions.input', 'Lev2_AN', 'Lev2_AA', 'Lev2_AC', 'GrInitialConditionsRingdown.input', 'RefinementOptionHistory.input', 'GaugeItems.input', 'Lev2_AG', 'Lev3_AT', 'Lev2_AE', 'Lev3_AL', 'Lev2_AQ', 'GrObservers.input', 'Lev3_AG', 'GrStateChangers.input', 'Lev3_AN', 'AmrTolerances.input', 'GrDataBoxItemsRingdown.input', 'Lev3_Ringdown', 'ConstraintDamping.input', 'GrWaveExtraction.input', 'ApparentHorizonFindersRingdown.input', 'DoMultipleRunsRingdown.input', 'Lev3_AI', 'GrSetupAndEvolution.input', 'Lev3_AS', 'DoMultipleRuns.input']
# Available lev dirs ['Lev2_AP', 'Lev2_AF', 'Lev3_AR', 'Lev3_AO', 'Lev3_AC', 'Lev3_AM', 'Lev2_AD', 'Lev3_AP', 'Lev3_AQ', 'Lev2_AM', 'Lev3_AE', 'Lev3_AF', 'Lev2_AB', 'Lev2_AO', 'Lev3_AU', 'Lev2_AI', 'Lev2_AL', 'Lev3_AK', 'Lev2_AH', 'Lev3_AV', 'Lev2_AR', 'Lev3_AD', 'Lev3_AH', 'Lev3_AJ', 'Lev2_AK', 'Lev3_AB', 'Lev2_AJ', 'Lev2_AS', 'Lev3_AA', 'Lev2_AN', 'Lev2_AA', 'Lev2_AC', 'Lev2_AG', 'Lev3_AT', 'Lev2_AE', 'Lev3_AL', 'Lev2_AQ', 'Lev3_AG', 'Lev3_AN', 'Lev3_AI', 'Lev3_AS']
# Available ringdown lev dirs ['Lev2_Ringdown', 'Lev3_Ringdown']
# Available levs {2, 3}
# Available ringdown levs {2, 3}
# Loading segments in EccContPrecDiff004
# Available dirs ['AmrDriver.input', 'bin', 'Lev2_AF', 'SpEC', 'GrVolumeDumps.input', 'ProhibitStartJobReruns.txt', 'Evolution.input', 'Lev3_AC', 'Lev3_AM', 'Lev2_AD', 'AmrTolerancesRingdown.input', 'Lev2_AM', 'Lev3_AE', 'AmrDriverRingdown.input', 'Lev2_Ringdown', 'Lev3_AF', 'EvolutionRingdown.input', 'CombinedStateChangers.input', 'Lev2_AB', 'ApparentHorizonFinders.input', 'GrDataBoxItems.input', 'Lev2_AI', 'GrBoundaryConditions.input', 'Lev2_AL', 'Lev3_AK', 'GrSetupAndEvolutionRingdown.input', 'Lev2_AH', 'Lev3_AD', 'Lev3_AH', 'Lev3_AJ', 'Lev2_AK', 'Lev3_AB', 'PBandJ_StartJob.sh', 'SpatialCoordMap.input', 'ConstraintDampingRingdown.input', 'GrObserversRingdown.input', 'Lev2_AJ', 'GrObservers.input.new', 'CombinedObservers.input', 'GrDomain.input', 'Lev3_AA', 'StartJob.sh', 'GrInitialConditions.input', 'Lev2_AN', 'Lev2_AA', 'Lev2_AC', 'GrInitialConditionsRingdown.input', 'RefinementOptionHistory.input', 'GaugeItems.input', 'Lev2_AG', 'Lev2_AE', 'Lev3_AL', 'GrObservers.input', 'Lev3_AG', 'GrStateChangers.input', 'Lev3_AN', 'AmrTolerances.input', 'GrDataBoxItemsRingdown.input', 'Lev3_Ringdown', 'ConstraintDamping.input', 'GrWaveExtraction.input', 'ApparentHorizonFindersRingdown.input', 'DoMultipleRunsRingdown.input', 'Lev3_AI', 'GrSetupAndEvolution.input', 'DoMultipleRuns.input']
# Available lev dirs ['Lev2_AF', 'Lev3_AC', 'Lev3_AM', 'Lev2_AD', 'Lev2_AM', 'Lev3_AE', 'Lev3_AF', 'Lev2_AB', 'Lev2_AI', 'Lev2_AL', 'Lev3_AK', 'Lev2_AH', 'Lev3_AD', 'Lev3_AH', 'Lev3_AJ', 'Lev2_AK', 'Lev3_AB', 'Lev2_AJ', 'Lev3_AA', 'Lev2_AN', 'Lev2_AA', 'Lev2_AC', 'Lev2_AG', 'Lev2_AE', 'Lev3_AL', 'Lev3_AG', 'Lev3_AN', 'Lev3_AI']
# Available ringdown lev dirs ['Lev2_Ringdown', 'Lev3_Ringdown']
# Available levs {2, 3}
# Available ringdown levs {2, 3}
# Loading segments in EccContPrecDiff001
# Available dirs ['Lev4_BS', 'Lev3_BG', 'ApparentHorizonFinders.input', 'Lev4_AM', 'PBandJ_StartJob.sh', 'Lev4_AZ', 'Lev3_BE', 'EvolutionRingdown.input', 'Lev3_BL', 'GrSetupAndEvolutionRingdown.input', 'GrObservers.input', 'RefinementOptionHistory.input', 'Lev4_AU', 'Lev3_BH', 'Lev3_BC', 'Lev3_BO', 'Lev3_AV', 'Lev3_AL', 'DoMultipleRunsRingdown.input', 'Lev4_AQ', 'GrStateChangers.input', 'Lev4_BF', 'Lev3_BT', 'Lev4_AK', 'Lev3_BI', 'Lev4_AJ', 'Lev4_AP', 'Lev4_AF', 'Lev3_AG', 'Lev3_AX', 'Lev3_BD', 'Lev3_AE', 'Lev3_AI', 'Evolution.input', 'Lev3_BB', 'Lev3_AD', 'Lev4_BW', 'Lev3_AA', 'Lev3_AP', 'Lev3_BK', 'Lev3_BQ', 'Lev4_AC', 'Lev3_AS', 'Lev4_BZ', 'Lev3_AB', 'GrInitialConditions.input', 'Lev3_BR', 'Lev4_BQ', 'Lev4_AW', 'Lev4_BY', 'GrDomain.input', 'Lev3_AU', 'Lev3_AW', 'Lev3_AJ', 'Lev4_AO', 'AmrDriverRingdown.input', 'Lev4_AV', 'Lev3_Ringdown', 'Lev4_AR', 'Lev4_CB', 'Lev3_AK', 'Lev4_BV', 'StartJob.sh', 'Lev4_BH', 'Lev4_AN', 'GrDataBoxItemsRingdown.input', 'CombinedObservers.input', 'AmrDriver.input', 'Lev4_AB', 'Lev4_BG', 'Lev4_BN', 'Lev4_AI', 'Lev3_BN', 'Lev3_AQ', 'Lev3_AH', 'Lev4_BD', 'Lev4_BU', 'CombinedStateChangers.input', 'GrVolumeDumps.input', 'Lev3_BJ', 'Lev4_BJ', 'Lev4_AS', 'Lev4_BC', 'bin', 'ApparentHorizonFindersRingdown.input', 'Lev3_AN', 'GrInitialConditionsRingdown.input', 'Lev4_BK', 'Lev3_BS', 'Lev3_AC', 'AmrTolerancesRingdown.input', 'Lev4_AT', 'GaugeItems.input', 'Lev4_BR', 'Lev3_BP', 'GrObserversRingdown.input', 'SpEC', 'Lev4_Ringdown', 'Lev4_BA', 'Lev3_BF', 'Lev4_BB', 'Lev3_AM', 'AmrTolerances.input', 'Lev4_BE', 'Lev4_BO', 'Lev4_AL', 'Lev3_AR', 'Lev4_AY', 'Lev3_AF', 'Lev4_AE', 'SpatialCoordMap.input', 'ConstraintDampingRingdown.input', 'Lev3_AO', 'Lev3_BM', 'Lev4_BT', 'Lev3_BA', 'Lev3_AY', 'GrObservers.input.new', 'Lev4_AA', 'Lev3_AZ', 'Lev4_AG', 'Lev3_BU', 'Lev4_BI', 'Lev4_BX', 'Lev4_BP', 'GrDataBoxItems.input', 'GrWaveExtraction.input', 'DoMultipleRuns.input', 'Lev3_AT', 'ProhibitStartJobReruns.txt', 'Lev4_AD', 'GrSetupAndEvolution.input', 'Lev4_BL', 'Lev4_CA', 'Lev4_AH', 'ConstraintDamping.input', 'Lev4_BM', 'GrBoundaryConditions.input', 'Lev4_AX']
# Available lev dirs ['Lev4_BS', 'Lev3_BG', 'Lev4_AM', 'Lev4_AZ', 'Lev3_BE', 'Lev3_BL', 'Lev4_AU', 'Lev3_BH', 'Lev3_BC', 'Lev3_BO', 'Lev3_AV', 'Lev3_AL', 'Lev4_AQ', 'Lev4_BF', 'Lev3_BT', 'Lev4_AK', 'Lev3_BI', 'Lev4_AJ', 'Lev4_AP', 'Lev4_AF', 'Lev3_AG', 'Lev3_AX', 'Lev3_BD', 'Lev3_AE', 'Lev3_AI', 'Lev3_BB', 'Lev3_AD', 'Lev4_BW', 'Lev3_AA', 'Lev3_AP', 'Lev3_BK', 'Lev3_BQ', 'Lev4_AC', 'Lev3_AS', 'Lev4_BZ', 'Lev3_AB', 'Lev3_BR', 'Lev4_BQ', 'Lev4_AW', 'Lev4_BY', 'Lev3_AU', 'Lev3_AW', 'Lev3_AJ', 'Lev4_AO', 'Lev4_AV', 'Lev4_AR', 'Lev4_CB', 'Lev3_AK', 'Lev4_BV', 'Lev4_BH', 'Lev4_AN', 'Lev4_AB', 'Lev4_BG', 'Lev4_BN', 'Lev4_AI', 'Lev3_BN', 'Lev3_AQ', 'Lev3_AH', 'Lev4_BD', 'Lev4_BU', 'Lev3_BJ', 'Lev4_BJ', 'Lev4_AS', 'Lev4_BC', 'Lev3_AN', 'Lev4_BK', 'Lev3_BS', 'Lev3_AC', 'Lev4_AT', 'Lev4_BR', 'Lev3_BP', 'Lev4_BA', 'Lev3_BF', 'Lev4_BB', 'Lev3_AM', 'Lev4_BE', 'Lev4_BO', 'Lev4_AL', 'Lev3_AR', 'Lev4_AY', 'Lev3_AF', 'Lev4_AE', 'Lev3_AO', 'Lev3_BM', 'Lev4_BT', 'Lev3_BA', 'Lev3_AY', 'Lev4_AA', 'Lev3_AZ', 'Lev4_AG', 'Lev3_BU', 'Lev4_BI', 'Lev4_BX', 'Lev4_BP', 'Lev3_AT', 'Lev4_AD', 'Lev4_BL', 'Lev4_CA', 'Lev4_AH', 'Lev4_BM', 'Lev4_AX']
# Available ringdown lev dirs ['Lev3_Ringdown', 'Lev4_Ringdown']
# Available levs {3, 4}
# Available ringdown levs {3, 4}
# Fetching last segment for sim EccContPrecDiff008, lev2
# Lines from SpEC.out ['t=6574.0, step=19672, T=27.880h, dt/dT=42.0/h, d(CPU-h)/dt=1.0226CPU-h/M\n', 't=6574.0, CpuUsage 1199  CPU-h, 2.66h startup, 0.21h 1st step, CPU-h/t=0.18\n', 'Termination condition FinalTime\n']
# Checking if the sim is running...
# Running jobs  [10972, 10973, 10974, 9017, 10963, 10962, 10961, 10966, 10817, 10964, 10969, 10970, 10953, 10971, 10952, 10968, 10967]
# sim job id 8843
# Segment runnint 2 False
# Error files []
# Sim status is unknown
# Fetching last segment for sim EccContPrecDiff008, lev3
# Lines from SpEC.out ['t=6579.0, step=21414, T=37.760h, dt/dT=10.7/h, d(CPU-h)/dt=4.0261CPU-h/M\n', 't=6579.0, CpuUsage 1624  CPU-h, 4.86h startup, 0.23h 1st step, CPU-h/t=0.25\n', 'Termination condition FinalTime\n']
# Checking if the sim is running...
# Running jobs  [10972, 10973, 10974, 9017, 10963, 10962, 10961, 10966, 10817, 10964, 10969, 10970, 10953, 10971, 10952, 10968, 10967]
# sim job id 8855
# Segment runnint 2 False
# Error files []
# Sim status is unknown
# Fetching last segment for sim EccContPrecDiff005, lev2
# Lines from SpEC.out ['t=1510.0, step=17338, T=23.789h, dt/dT=45.7/h, d(CPU-h)/dt=0.8099CPU-h/M\n', 't=1510.0, CpuUsage 880.2 CPU-h, 2.18h startup, 0.12h 1st step, CPU-h/t=0.58\n', 'Termination condition FinalTime\n']
# Checking if the sim is running...
# Running jobs  [10972, 10973, 10974, 9017, 10963, 10962, 10961, 10966, 10817, 10964, 10969, 10970, 10953, 10971, 10952, 10968, 10967]
# sim job id 8688
# Segment runnint 2 False
# Error files []
# Sim status is unknown
# Fetching last segment for sim EccContPrecDiff005, lev3
# Lines from SpEC.out ['t=1510.0, step=18920, T=35.864h, dt/dT=38.2/h, d(CPU-h)/dt=0.9691CPU-h/M\n', 't=1510.0, CpuUsage 1327  CPU-h, 3.52h startup, 0.17h 1st step, CPU-h/t=0.88\n', 'Termination condition FinalTime\n']
# Checking if the sim is running...
# Running jobs  [10972, 10973, 10974, 9017, 10963, 10962, 10961, 10966, 10817, 10964, 10969, 10970, 10953, 10971, 10952, 10968, 10967]
# sim job id 8696
# Segment runnint 2 False
# Error files []
# Sim status is unknown
# Fetching last segment for sim EccContPrecDiff003, lev2
# Lines from SpEC.out ['t=1813.0, step=17439, T=42.165h, dt/dT=48.9/h, d(CPU-h)/dt=0.7561CPU-h/M\n', 't=1813.0, CpuUsage 1560  CPU-h, 14.9h startup, 0.39h 1st step, CPU-h/t=0.86\n', 'Termination condition FinalTime\n']
# Checking if the sim is running...
# Running jobs  [10972, 10973, 10974, 9017, 10963, 10962, 10961, 10966, 10817, 10964, 10969, 10970, 10953, 10971, 10952, 10968, 10967]
# sim job id 8772
# Segment runnint 2 False
# Error files []
# Sim status is unknown
# Fetching last segment for sim EccContPrecDiff003, lev3
# Fetching last segment for sim EccContPrecDiff006, lev2
# Lines from SpEC.out ['t=1719.0, step=17450, T=26.944h, dt/dT=45.2/h, d(CPU-h)/dt=0.8190CPU-h/M\n', 't=1719.0, CpuUsage 997.0 CPU-h, 4.46h startup, 0.22h 1st step, CPU-h/t=0.58\n', 'Termination condition FinalTime\n']
# Checking if the sim is running...
# Running jobs  [10972, 10973, 10974, 9017, 10963, 10962, 10961, 10966, 10817, 10964, 10969, 10970, 10953, 10971, 10952, 10968, 10967]
# sim job id 8770
# Segment runnint 2 False
# Error files []
# Sim status is unknown
# Fetching last segment for sim EccContPrecDiff006, lev3
# Lines from SpEC.out ['t=1719.0, step=18469, T=36.967h, dt/dT=36.4/h, d(CPU-h)/dt=1.0175CPU-h/M\n', 't=1719.0, CpuUsage 1368  CPU-h, 7.53h startup, 0.29h 1st step, CPU-h/t=0.80\n', 'Termination condition FinalTime\n']
# Checking if the sim is running...
# Running jobs  [10972, 10973, 10974, 9017, 10963, 10962, 10961, 10966, 10817, 10964, 10969, 10970, 10953, 10971, 10952, 10968, 10967]
# sim job id 8695
# Segment runnint 2 False
# Error files []
# Sim status is unknown
# Fetching last segment for sim EccContPrecDiff002, lev3
# Lines from SpEC.out ['t=7259.5, step=534262, T=17.000h, dt/dT=24.7/h, d(CPU-h)/dt=1.9402CPU-h/M\n', 't=7283.6, step=536145, T=18.000h, dt/dT=24.1/h, d(CPU-h)/dt=1.9879CPU-h/M\n', 't=7307.0, step=538000, T=19.000h, dt/dT=23.4/h, d(CPU-h)/dt=2.0485CPU-h/M\n']
# Checking if the sim is running...
# Running jobs  [10972, 10973, 10974, 9017, 10963, 10962, 10961, 10966, 10817, 10964, 10969, 10970, 10953, 10971, 10952, 10968, 10967]
# sim job id 8616
# Segment runnint 2 False
# Error files []
# Sim status is unknown
# Fetching last segment for sim EccContPrecDiff002, lev4
# Lines from SpEC.out ['\n', '#  And so it begins...\n', 't=2873.9, step=218069, T=3.25sec (just starting evolution) \n']
# Checking if the sim is running...
# Running jobs  [10972, 10973, 10974, 9017, 10963, 10962, 10961, 10966, 10817, 10964, 10969, 10970, 10953, 10971, 10952, 10968, 10967]
# sim job id 8405
# Segment runnint 2 False
# Error files []
# Sim status is unknown
# Fetching last segment for sim EccContPrecDiff007, lev2
# Lines from SpEC.out ['t=4206.0, step=17929, T=34.252h, dt/dT=49.5/h, d(CPU-h)/dt=0.7683CPU-h/M\n', 't=4206.0, CpuUsage 1302  CPU-h, 10.4h startup, 0.33h 1st step, CPU-h/t=0.31\n', 'Termination condition FinalTime\n']
# Checking if the sim is running...
# Running jobs  [10972, 10973, 10974, 9017, 10963, 10962, 10961, 10966, 10817, 10964, 10969, 10970, 10953, 10971, 10952, 10968, 10967]
# sim job id 8795
# Segment runnint 2 False
# Error files []
# Sim status is unknown
# Fetching last segment for sim EccContPrecDiff007, lev3
# Lines from SpEC.out ['t=4205.0, step=17909, T=46.533h, dt/dT=35.0/h, d(CPU-h)/dt=1.0852CPU-h/M\n', 't=4205.0, CpuUsage 1768  CPU-h, 18.9h startup, 0.50h 1st step, CPU-h/t=0.42\n', 'Termination condition FinalTime\n']
# Checking if the sim is running...
# Running jobs  [10972, 10973, 10974, 9017, 10963, 10962, 10961, 10966, 10817, 10964, 10969, 10970, 10953, 10971, 10952, 10968, 10967]
# sim job id 8829
# Segment runnint 2 False
# Error files []
# Sim status is unknown
# Fetching last segment for sim EccContPrecDiff004, lev2
# Lines from SpEC.out ['t=1870.0, step=19016, T=27.464h, dt/dT=39.8/h, d(CPU-h)/dt=0.9304CPU-h/M\n', 't=1870.0, CpuUsage 1016  CPU-h, 3.39h startup, 0.16h 1st step, CPU-h/t=0.54\n', 'Termination condition FinalTime\n']
# Checking if the sim is running...
# Running jobs  [10972, 10973, 10974, 9017, 10963, 10962, 10961, 10966, 10817, 10964, 10969, 10970, 10953, 10971, 10952, 10968, 10967]
# sim job id 8687
# Segment runnint 2 False
# Error files []
# Sim status is unknown
# Fetching last segment for sim EccContPrecDiff004, lev3
# Lines from SpEC.out ['t=1870.0, step=24574, T=46.106h, dt/dT=26.0/h, d(CPU-h)/dt=1.4223CPU-h/M\n', 't=1870.0, CpuUsage 1706  CPU-h, 4.92h startup, 0.22h 1st step, CPU-h/t=0.91\n', 'Termination condition FinalTime\n']
# Checking if the sim is running...
# Running jobs  [10972, 10973, 10974, 9017, 10963, 10962, 10961, 10966, 10817, 10964, 10969, 10970, 10953, 10971, 10952, 10968, 10967]
# sim job id 9273
# Segment runnint 2 False
# Error files []
# Sim status is unknown
# Fetching last segment for sim EccContPrecDiff001, lev3
# Lines from SpEC.out ['t=22237 , step=29102, T=4.75min, dt/dT=44.1/h, d(CPU-h)/dt=1.0889CPU-h/M\n', 't=22237 , CpuUsage 4302  CPU-h, 34.0h startup, 4.79h 1st step, CPU-h/t=0.19\n', 'Termination condition FinalTime\n']
# Checking if the sim is running...
# Running jobs  [10972, 10973, 10974, 9017, 10963, 10962, 10961, 10966, 10817, 10964, 10969, 10970, 10953, 10971, 10952, 10968, 10967]
# sim job id 8937
# Segment runnint 2 False
# Error files []
# Sim status is unknown
# Fetching last segment for sim EccContPrecDiff001, lev4
# Lines from SpEC.out ['t=22215 , step=32513, T=6.2428h, dt/dT=32.0/h, d(CPU-h)/dt=1.5002CPU-h/M\n', 't=22215 , CpuUsage 6508  CPU-h, 77.0h startup, 7.13h 1st step, CPU-h/t=0.29\n', 'Termination condition FinalTime\n']
# Checking if the sim is running...
# Running jobs  [10972, 10973, 10974, 9017, 10963, 10962, 10961, 10966, 10817, 10964, 10969, 10970, 10953, 10971, 10952, 10968, 10967]
# sim job id 9055
# Segment runnint 2 False
# Error files []
# Sim status is unknown
# Computing ncycles for EccContPrecDiff008 Lev2
# Joined Horizons.h5 file already found in /mnt/pfs/vaishak.p/Projects/Codes/waveforms/EccContPrecDiff008_waveforms_Lev2/joined/EccContPrecDiff008Lev2JoinedHorizons.h5
# Computing ncycles for EccContPrecDiff008 Lev3
# Joined Horizons.h5 file already found in /mnt/pfs/vaishak.p/Projects/Codes/waveforms/EccContPrecDiff008_waveforms_Lev3/joined/EccContPrecDiff008Lev3JoinedHorizons.h5
# Computing ncycles for EccContPrecDiff005 Lev2
# Joined Horizons.h5 file already found in /mnt/pfs/vaishak.p/Projects/Codes/waveforms/EccContPrecDiff005_waveforms_Lev2/joined/EccContPrecDiff005Lev2JoinedHorizons.h5
# Computing ncycles for EccContPrecDiff005 Lev3
# Joined Horizons.h5 file already found in /mnt/pfs/vaishak.p/Projects/Codes/waveforms/EccContPrecDiff005_waveforms_Lev3/joined/EccContPrecDiff005Lev3JoinedHorizons.h5
# Computing ncycles for EccContPrecDiff003 Lev2
# Joined Horizons.h5 file already found in /mnt/pfs/vaishak.p/Projects/Codes/waveforms/EccContPrecDiff003_waveforms_Lev2/joined/EccContPrecDiff003Lev2JoinedHorizons.h5
# Computing ncycles for EccContPrecDiff003 Lev3
# Choosing default directory for output...
# Out directory is set to /mnt/pfs/vaishak.p/Projects/Codes/waveforms
# Joining Horizon h5 files...
# data paths insp /mnt/pfs/vaishak.p/sims/SpEC/gcc/bfi/EccContPrecDiff/EccContPrecDiff003/Ecc0/Ev/Lev3*/Run/ApparentHorizons/Horizons.h5
# data paths rdown /mnt/pfs/vaishak.p/sims/SpEC/gcc/bfi/EccContPrecDiff/EccContPrecDiff003/Ecc0/Ev/Lev3_Ringdown/Lev3*/Run/ApparentHorizons/Horizons.h5
# Running command
#  JoinH5 -o /mnt/pfs/vaishak.p/Projects/Codes/waveforms/joined/EccContPrecDiff003Lev3JoinedHorizons.h5 /mnt/pfs/vaishak.p/sims/SpEC/gcc/bfi/EccContPrecDiff/EccContPrecDiff003/Ecc0/Ev/Lev3*/Run/ApparentHorizons/Horizons.h5 /mnt/pfs/vaishak.p/sims/SpEC/gcc/bfi/EccContPrecDiff/EccContPrecDiff003/Ecc0/Ev/Lev3_Ringdown/Lev3*/Run/ApparentHorizons/Horizons.h5
# [??]
# #######################  REQUIRE  FAILED  #######################
# #### FileExists(Filenames[i])  violated
# #### JoinH5.cpp (line 176)
# File /mnt/pfs/vaishak.p/sims/SpEC/gcc/bfi/EccContPrecDiff/EccContPrecDiff003/Ecc0/Ev/Lev3_Ringdown/Lev3*/Run/ApparentHorizons/Horizons.h5 not found
# #################################################################
#
# 0  libErrorHandling.so  0x7fe558411410  CodeError::CodeError(std::__cxx11::basic_string<char, std::char_traits<char>, std::allocator<char> >, bool) + 96
# 1  libErrorHandling.so  0x7fe55840d8d8  0x0 + 140623004883160
# 2  JoinH5               0x5650f06112b2  main + 17602
# 3  libc.so.6            0x7fe54dd6c555  __libc_start_main + 245
# 4  JoinH5               0x5650f0612937  0x0 + 94905630271799
# Command output
#
# Command completed. Please check Errors.txt for details.
# [Errno 2] Unable to synchronously open file (unable to open file: name = '/mnt/pfs/vaishak.p/Projects/Codes/waveforms/joined/EccContPrecDiff003Lev3JoinedHorizons.h5', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0) Skipping EccContPrecDiff003 Lev3
# Computing ncycles for EccContPrecDiff006 Lev2
# Joined Horizons.h5 file already found in /mnt/pfs/vaishak.p/Projects/Codes/waveforms/EccContPrecDiff006_waveforms_Lev2/joined/EccContPrecDiff006Lev2JoinedHorizons.h5
# Computing ncycles for EccContPrecDiff006 Lev3
# Joined Horizons.h5 file already found in /mnt/pfs/vaishak.p/Projects/Codes/waveforms/EccContPrecDiff006_waveforms_Lev3/joined/EccContPrecDiff006Lev3JoinedHorizons.h5
# Computing ncycles for EccContPrecDiff002 Lev3
# Choosing default directory for output...
# Out directory is set to /mnt/pfs/vaishak.p/Projects/Codes/waveforms
# Joining Horizon h5 files...
# data paths insp /mnt/pfs/vaishak.p/sims/SpEC/gcc/bfi/EccContPrecDiff/EccContPrecDiff002/Ecc0/Ev/Lev3*/Run/ApparentHorizons/Horizons.h5
# data paths rdown /mnt/pfs/vaishak.p/sims/SpEC/gcc/bfi/EccContPrecDiff/EccContPrecDiff002/Ecc0/Ev/Lev3_Ringdown/Lev3*/Run/ApparentHorizons/Horizons.h5
# Running command
#  JoinH5 -o /mnt/pfs/vaishak.p/Projects/Codes/waveforms/joined/EccContPrecDiff002Lev3JoinedHorizons.h5 /mnt/pfs/vaishak.p/sims/SpEC/gcc/bfi/EccContPrecDiff/EccContPrecDiff002/Ecc0/Ev/Lev3*/Run/ApparentHorizons/Horizons.h5 /mnt/pfs/vaishak.p/sims/SpEC/gcc/bfi/EccContPrecDiff/EccContPrecDiff002/Ecc0/Ev/Lev3_Ringdown/Lev3*/Run/ApparentHorizons/Horizons.h5
# [??]
# #######################  REQUIRE  FAILED  #######################
# #### FileExists(Filenames[i])  violated
# #### JoinH5.cpp (line 176)
# File /mnt/pfs/vaishak.p/sims/SpEC/gcc/bfi/EccContPrecDiff/EccContPrecDiff002/Ecc0/Ev/Lev3_Ringdown/Lev3*/Run/ApparentHorizons/Horizons.h5 not found
# #################################################################
#
# 0  libErrorHandling.so  0x7f020a1f0410  CodeError::CodeError(std::__cxx11::basic_string<char, std::char_traits<char>, std::allocator<char> >, bool) + 96
# 1  libErrorHandling.so  0x7f020a1ec8d8  0x0 + 139646736451800
# 2  JoinH5               0x55914512c2b2  main + 17602
# 3  libc.so.6            0x7f01ffb4b555  __libc_start_main + 245
# 4  JoinH5               0x55914512d937  0x0 + 94082417482039
# Command output
#
# Command completed. Please check Errors.txt for details.
# [Errno 2] Unable to synchronously open file (unable to open file: name = '/mnt/pfs/vaishak.p/Projects/Codes/waveforms/joined/EccContPrecDiff002Lev3JoinedHorizons.h5', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0) Skipping EccContPrecDiff002 Lev3
# Computing ncycles for EccContPrecDiff002 Lev4
# Choosing default directory for output...
# Out directory is set to /mnt/pfs/vaishak.p/Projects/Codes/waveforms
# Joining Horizon h5 files...
# data paths insp /mnt/pfs/vaishak.p/sims/SpEC/gcc/bfi/EccContPrecDiff/EccContPrecDiff002/Ecc0/Ev/Lev4*/Run/ApparentHorizons/Horizons.h5
# data paths rdown /mnt/pfs/vaishak.p/sims/SpEC/gcc/bfi/EccContPrecDiff/EccContPrecDiff002/Ecc0/Ev/Lev4_Ringdown/Lev4*/Run/ApparentHorizons/Horizons.h5
# Running command
#  JoinH5 -o /mnt/pfs/vaishak.p/Projects/Codes/waveforms/joined/EccContPrecDiff002Lev4JoinedHorizons.h5 /mnt/pfs/vaishak.p/sims/SpEC/gcc/bfi/EccContPrecDiff/EccContPrecDiff002/Ecc0/Ev/Lev4*/Run/ApparentHorizons/Horizons.h5 /mnt/pfs/vaishak.p/sims/SpEC/gcc/bfi/EccContPrecDiff/EccContPrecDiff002/Ecc0/Ev/Lev4_Ringdown/Lev4*/Run/ApparentHorizons/Horizons.h5
# [??]
# #######################  REQUIRE  FAILED  #######################
# #### FileExists(Filenames[i])  violated
# #### JoinH5.cpp (line 176)
# File /mnt/pfs/vaishak.p/sims/SpEC/gcc/bfi/EccContPrecDiff/EccContPrecDiff002/Ecc0/Ev/Lev4_Ringdown/Lev4*/Run/ApparentHorizons/Horizons.h5 not found
# #################################################################
#
# 0  libErrorHandling.so  0x7ff39629c410  CodeError::CodeError(std::__cxx11::basic_string<char, std::char_traits<char>, std::allocator<char> >, bool) + 96
# 1  libErrorHandling.so  0x7ff3962988d8  0x0 + 140684173084888
# 2  JoinH5               0x559d647172b2  main + 17602
# 3  libc.so.6            0x7ff38bbf7555  __libc_start_main + 245
# 4  JoinH5               0x559d64718937  0x0 + 94134483388727
# Command output
#
# Command completed. Please check Errors.txt for details.
# [Errno 2] Unable to synchronously open file (unable to open file: name = '/mnt/pfs/vaishak.p/Projects/Codes/waveforms/joined/EccContPrecDiff002Lev4JoinedHorizons.h5', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0) Skipping EccContPrecDiff002 Lev4
# Computing ncycles for EccContPrecDiff007 Lev2
# Joined Horizons.h5 file already found in /mnt/pfs/vaishak.p/Projects/Codes/waveforms/EccContPrecDiff007_waveforms_Lev2/joined/EccContPrecDiff007Lev2JoinedHorizons.h5
# Computing ncycles for EccContPrecDiff007 Lev3
# Joined Horizons.h5 file already found in /mnt/pfs/vaishak.p/Projects/Codes/waveforms/EccContPrecDiff007_waveforms_Lev3/joined/EccContPrecDiff007Lev3JoinedHorizons.h5
# Computing ncycles for EccContPrecDiff004 Lev2
# Joined Horizons.h5 file already found in /mnt/pfs/vaishak.p/Projects/Codes/waveforms/EccContPrecDiff004_waveforms_Lev2/joined/EccContPrecDiff004Lev2JoinedHorizons.h5
# Computing ncycles for EccContPrecDiff004 Lev3
# Choosing default directory for output...
# Out directory is set to /mnt/pfs/vaishak.p/Projects/Codes/waveforms
# File already exists. Skipping join horizons operation.
# Computing ncycles for EccContPrecDiff001 Lev3
# Joined Horizons.h5 file already found in /mnt/pfs/vaishak.p/Projects/Codes/waveforms/EccContPrecDiff001_waveforms_Lev3/joined/EccContPrecDiff001Lev3JoinedHorizons.h5
# Computing ncycles for EccContPrecDiff001 Lev4
# Joined Horizons.h5 file already found in /mnt/pfs/vaishak.p/Projects/Codes/waveforms/EccContPrecDiff001_waveforms_Lev4/joined/EccContPrecDiff001Lev4JoinedHorizons.h5
# Computing ncycles for EccContPrecDiff008 Lev2
# Computing ncycles for EccContPrecDiff008 Lev3
# Computing ncycles for EccContPrecDiff005 Lev2
# Computing ncycles for EccContPrecDiff005 Lev3
# Computing ncycles for EccContPrecDiff003 Lev2
# Computing ncycles for EccContPrecDiff003 Lev3
# [Errno 2] Unable to synchronously open file (unable to open file: name = '/mnt/pfs/vaishak.p/Projects/Codes/waveforms/EccContPrecDiff003_waveforms_Lev3/extrapolated/rhOverM_Extrapolated_N2_CoM.h5', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0) Skipping EccContPrecDiff003 Lev3
# Computing ncycles for EccContPrecDiff006 Lev2
# [Errno 2] Unable to synchronously open file (unable to open file: name = '/mnt/pfs/vaishak.p/Projects/Codes/waveforms/EccContPrecDiff006_waveforms_Lev2/extrapolated/rhOverM_Extrapolated_N2_CoM.h5', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0) Skipping EccContPrecDiff006 Lev2
# Computing ncycles for EccContPrecDiff006 Lev3
# Computing ncycles for EccContPrecDiff002 Lev3
# [Errno 2] Unable to synchronously open file (unable to open file: name = '/mnt/pfs/vaishak.p/Projects/Codes/waveforms/EccContPrecDiff002_waveforms_Lev3/extrapolated/rhOverM_Extrapolated_N2_CoM.h5', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0) Skipping EccContPrecDiff002 Lev3
# Computing ncycles for EccContPrecDiff002 Lev4
# [Errno 2] Unable to synchronously open file (unable to open file: name = '/mnt/pfs/vaishak.p/Projects/Codes/waveforms/EccContPrecDiff002_waveforms_Lev4/extrapolated/rhOverM_Extrapolated_N2_CoM.h5', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0) Skipping EccContPrecDiff002 Lev4
# Computing ncycles for EccContPrecDiff007 Lev2
# Computing ncycles for EccContPrecDiff007 Lev3
# Computing ncycles for EccContPrecDiff004 Lev2
# [Errno 2] Unable to synchronously open file (unable to open file: name = '/mnt/pfs/vaishak.p/Projects/Codes/waveforms/EccContPrecDiff004_waveforms_Lev2/extrapolated/rhOverM_Extrapolated_N2_CoM.h5', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0) Skipping EccContPrecDiff004 Lev2
# Computing ncycles for EccContPrecDiff004 Lev3
# [Errno 2] Unable to synchronously open file (unable to open file: name = '/mnt/pfs/vaishak.p/Projects/Codes/waveforms/EccContPrecDiff004_waveforms_Lev3/extrapolated/rhOverM_Extrapolated_N2_CoM.h5', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0) Skipping EccContPrecDiff004 Lev3
# Computing ncycles for EccContPrecDiff001 Lev3
# Computing ncycles for EccContPrecDiff001 Lev4

# %%
se.all_sim_params_df
# Out:
#                     Sl. No.                            Status    Omega0  \
# EccContPrecDiff001        1  {3: 'Completed', 4: 'Completed'}  0.010373
# EccContPrecDiff002        2        {3: 'Halted', 4: 'Halted'}  0.007994
# EccContPrecDiff003        3         {2: 'Completed', 3: None}  0.028386
# EccContPrecDiff004        4  {2: 'Completed', 3: 'Completed'}  0.031291
# EccContPrecDiff005        5  {2: 'Completed', 3: 'Completed'}  0.033129
# EccContPrecDiff006        6  {2: 'Completed', 3: 'Completed'}  0.027823
# EccContPrecDiff007        7  {2: 'Completed', 3: 'Completed'}  0.017183
# EccContPrecDiff008        8  {2: 'Completed', 3: 'Completed'}  0.018468
#
#                                                            Ncycles  \
# EccContPrecDiff001  {3: 103.01430054967433, 4: 102.95066161184174}
# EccContPrecDiff002                                              {}
# EccContPrecDiff003                         {2: 14.224607497794048}
# EccContPrecDiff004   {2: 14.74091510773156, 3: 15.648219173738543}
# EccContPrecDiff005  {2: 10.900573211367973, 3: 10.900875019299674}
# EccContPrecDiff006  {2: 13.311119330379896, 3: 13.325567918834619}
# EccContPrecDiff007    {2: 30.4822281886772, 3: 30.488054612491805}
# EccContPrecDiff008     {2: 40.21426704175213, 3: 40.2427412095804}
#
#                                                     Ncycles (2,2)     adot0  \
# EccContPrecDiff001  {3: 107.41976856783918, 4: 107.2966440688715}  0.000141
# EccContPrecDiff002                                             {}  0.000556
# EccContPrecDiff003                         {2: 17.51906258699352}       0.0
# EccContPrecDiff004                                             {}       0.0
# EccContPrecDiff005    {2: 12.106245796855, 3: 12.108582183910833}       0.0
# EccContPrecDiff006                        {3: 17.132439666082558}  0.003659
# EccContPrecDiff007  {2: 30.51949011892798, 3: 30.510827762781076}  0.001049
# EccContPrecDiff008   {2: 40.69528814795823, 3: 40.73781477765863}       0.0
#
#                            D0 MassRatio              ChiA              ChiB  \
# EccContPrecDiff001    20.2307       3.0   (0.3, 0.0, 0.0)   (0.2, 0.0, 0.1)
# EccContPrecDiff002   23.99403       2.5   (0.1, 0.4, 0.0)   (0.5, 0.0, 0.0)
# EccContPrecDiff003        9.9       3.5  (-0.2, 0.1, 0.0)  (0.2, 0.0, -0.3)
# EccContPrecDiff004       9.35       1.1   (0.0, 0.3, 0.2)   (0.0, 0.1, 0.5)
# EccContPrecDiff005       9.02       1.0   (0.3, 0.4, 0.0)   (0.0, 0.0, 0.0)
# EccContPrecDiff006  10.007926       1.5   (0.3, 0.3, 0.2)   (0.1, 0.0, 0.2)
# EccContPrecDiff007  13.986663       2.5   (0.1, 0.4, 0.0)   (0.5, 0.0, 0.0)
# EccContPrecDiff008      13.94       1.0   (0.3, 0.4, 0.0)   (0.0, 0.0, 0.0)
#
#                    IDType ReferenceTime SemiMajorAxis Eccentricity  \
# EccContPrecDiff001    SHK           0.0          21.0         0.04
# EccContPrecDiff002    SHK           0.0          24.0         0.08
# EccContPrecDiff003    SHK           0.0          11.0          0.1
# EccContPrecDiff004    SHK           0.0          11.0         0.15
# EccContPrecDiff005    SHK           0.0          11.0         0.18
# EccContPrecDiff006    SHK           0.0          11.0         0.21
# EccContPrecDiff007    SHK           0.0          14.0         0.08
# EccContPrecDiff008    SHK           0.0          17.0         0.18
#
#                    AnomalyAngle ZwickyDays    ChiEff   ChiPrec
# EccContPrecDiff001          0.4        0.0     0.025       0.3
# EccContPrecDiff002          1.5        0.0       0.0  0.412311
# EccContPrecDiff003          0.0        0.0 -0.066667  0.223607
# EccContPrecDiff004          0.0        0.0  0.342857       0.3
# EccContPrecDiff005          0.0        0.0       0.0       0.5
# EccContPrecDiff006          1.0        0.0       0.2  0.424264
# EccContPrecDiff007          1.5        0.0       0.0  0.412311
# EccContPrecDiff008          0.0        0.0       0.0       0.5

# %%
print(se.all_sim_params_df.to_markdown())
# Out:
# |                    |   Sl. No. | Status                           |     Omega0 | Ncycles                                        | Ncycles (2,2)                                 |       adot0 |      D0 |   MassRatio | ChiA             | ChiB             | IDType   |   ReferenceTime |   SemiMajorAxis |   Eccentricity |   AnomalyAngle |   ZwickyDays |     ChiEff |   ChiPrec |
# |:-------------------|----------:|:---------------------------------|-----------:|:-----------------------------------------------|:----------------------------------------------|------------:|--------:|------------:|:-----------------|:-----------------|:---------|----------------:|----------------:|---------------:|---------------:|-------------:|-----------:|----------:|
# | EccContPrecDiff001 |         1 | {3: 'Completed', 4: 'Completed'} | 0.0103729  | {3: 103.01430054967433, 4: 102.95066161184174} | {3: 107.41976856783918, 4: 107.2966440688715} | 0.000141159 | 20.2307 |         3   | (0.3, 0.0, 0.0)  | (0.2, 0.0, 0.1)  | SHK      |               0 |              21 |           0.04 |            0.4 |            0 |  0.025     |  0.3      |
# | EccContPrecDiff002 |         2 | {3: 'Halted', 4: 'Halted'}       | 0.00799436 | {}                                             | {}                                            | 0.000555982 | 23.994  |         2.5 | (0.1, 0.4, 0.0)  | (0.5, 0.0, 0.0)  | SHK      |               0 |              24 |           0.08 |            1.5 |            0 |  0         |  0.412311 |
# | EccContPrecDiff003 |         3 | {2: 'Completed', 3: None}        | 0.0283864  | {2: 14.224607497794048}                        | {2: 17.51906258699352}                        | 0           |  9.9    |         3.5 | (-0.2, 0.1, 0.0) | (0.2, 0.0, -0.3) | SHK      |               0 |              11 |           0.1  |            0   |            0 | -0.0666667 |  0.223607 |
# | EccContPrecDiff004 |         4 | {2: 'Completed', 3: 'Completed'} | 0.0312909  | {2: 14.74091510773156, 3: 15.648219173738543}  | {}                                            | 0           |  9.35   |         1.1 | (0.0, 0.3, 0.2)  | (0.0, 0.1, 0.5)  | SHK      |               0 |              11 |           0.15 |            0   |            0 |  0.342857  |  0.3      |
# | EccContPrecDiff005 |         5 | {2: 'Completed', 3: 'Completed'} | 0.0331294  | {2: 10.900573211367973, 3: 10.900875019299674} | {2: 12.106245796855, 3: 12.108582183910833}   | 0           |  9.02   |         1   | (0.3, 0.4, 0.0)  | (0.0, 0.0, 0.0)  | SHK      |               0 |              11 |           0.18 |            0   |            0 |  0         |  0.5      |
# | EccContPrecDiff006 |         6 | {2: 'Completed', 3: 'Completed'} | 0.0278232  | {2: 13.311119330379896, 3: 13.325567918834619} | {3: 17.132439666082558}                       | 0.00365934  | 10.0079 |         1.5 | (0.3, 0.3, 0.2)  | (0.1, 0.0, 0.2)  | SHK      |               0 |              11 |           0.21 |            1   |            0 |  0.2       |  0.424264 |
# | EccContPrecDiff007 |         7 | {2: 'Completed', 3: 'Completed'} | 0.0171827  | {2: 30.4822281886772, 3: 30.488054612491805}   | {2: 30.51949011892798, 3: 30.510827762781076} | 0.00104911  | 13.9867 |         2.5 | (0.1, 0.4, 0.0)  | (0.5, 0.0, 0.0)  | SHK      |               0 |              14 |           0.08 |            1.5 |            0 |  0         |  0.412311 |
# | EccContPrecDiff008 |         8 | {2: 'Completed', 3: 'Completed'} | 0.018468   | {2: 40.21426704175213, 3: 40.2427412095804}    | {2: 40.69528814795823, 3: 40.73781477765863}  | 0           | 13.94   |         1   | (0.3, 0.4, 0.0)  | (0.0, 0.0, 0.0)  | SHK      |               0 |              17 |           0.18 |            0   |            0 |  0         |  0.5      |

# %%
print(se.all_sim_params_df.to_html())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Sl. No.</th>
#       <th>Status</th>
#       <th>Omega0</th>
#       <th>Ncycles</th>
#       <th>Ncycles (2,2)</th>
#       <th>adot0</th>
#       <th>D0</th>
#       <th>MassRatio</th>
#       <th>ChiA</th>
#       <th>ChiB</th>
#       <th>IDType</th>
#       <th>ReferenceTime</th>
#       <th>SemiMajorAxis</th>
#       <th>Eccentricity</th>
#       <th>AnomalyAngle</th>
#       <th>ZwickyDays</th>
#       <th>ChiEff</th>
#       <th>ChiPrec</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>EccContPrecDiff001</th>
#       <td>1</td>
#       <td>{3: 'Completed', 4: 'Completed'}</td>
#       <td>0.010373</td>
#       <td>{3: 103.01430054967433, 4: 102.95066161184174}</td>
#       <td>{3: 107.41976856783918, 4: 107.2966440688715}</td>
#       <td>0.000141</td>
#       <td>20.2307</td>
#       <td>3.0</td>
#       <td>(0.3, 0.0, 0.0)</td>
#       <td>(0.2, 0.0, 0.1)</td>
#       <td>SHK</td>
#       <td>0.0</td>
#       <td>21.0</td>
#       <td>0.04</td>
#       <td>0.4</td>
#       <td>0.0</td>
#       <td>0.025</td>
#       <td>0.3</td>
#     </tr>
#     <tr>
#       <th>EccContPrecDiff002</th>
#       <td>2</td>
#       <td>{3: 'Halted', 4: 'Halted'}</td>
#       <td>0.007994</td>
#       <td>{}</td>
#       <td>{}</td>
#       <td>0.000556</td>
#       <td>23.99403</td>
#       <td>2.5</td>
#       <td>(0.1, 0.4, 0.0)</td>
#       <td>(0.5, 0.0, 0.0)</td>
#       <td>SHK</td>
#       <td>0.0</td>
#       <td>24.0</td>
#       <td>0.08</td>
#       <td>1.5</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.412311</td>
#     </tr>
#     <tr>
#       <th>EccContPrecDiff003</th>
#       <td>3</td>
#       <td>{2: 'Completed', 3: None}</td>
#       <td>0.028386</td>
#       <td>{2: 14.224607497794048}</td>
#       <td>{2: 17.51906258699352}</td>
#       <td>0.0</td>
#       <td>9.9</td>
#       <td>3.5</td>
#       <td>(-0.2, 0.1, 0.0)</td>
#       <td>(0.2, 0.0, -0.3)</td>
#       <td>SHK</td>
#       <td>0.0</td>
#       <td>11.0</td>
#       <td>0.1</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>-0.066667</td>
#       <td>0.223607</td>
#     </tr>
#     <tr>
#       <th>EccContPrecDiff004</th>
#       <td>4</td>
#       <td>{2: 'Completed', 3: 'Completed'}</td>
#       <td>0.031291</td>
#       <td>{2: 14.74091510773156, 3: 15.648219173738543}</td>
#       <td>{}</td>
#       <td>0.0</td>
#       <td>9.35</td>
#       <td>1.1</td>
#       <td>(0.0, 0.3, 0.2)</td>
#       <td>(0.0, 0.1, 0.5)</td>
#       <td>SHK</td>
#       <td>0.0</td>
#       <td>11.0</td>
#       <td>0.15</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.342857</td>
#       <td>0.3</td>
#     </tr>
#     <tr>
#       <th>EccContPrecDiff005</th>
#       <td>5</td>
#       <td>{2: 'Completed', 3: 'Completed'}</td>
#       <td>0.033129</td>
#       <td>{2: 10.900573211367973, 3: 10.900875019299674}</td>
#       <td>{2: 12.106245796855, 3: 12.108582183910833}</td>
#       <td>0.0</td>
#       <td>9.02</td>
#       <td>1.0</td>
#       <td>(0.3, 0.4, 0.0)</td>
#       <td>(0.0, 0.0, 0.0)</td>
#       <td>SHK</td>
#       <td>0.0</td>
#       <td>11.0</td>
#       <td>0.18</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.5</td>
#     </tr>
#     <tr>
#       <th>EccContPrecDiff006</th>
#       <td>6</td>
#       <td>{2: 'Completed', 3: 'Completed'}</td>
#       <td>0.027823</td>
#       <td>{2: 13.311119330379896, 3: 13.325567918834619}</td>
#       <td>{3: 17.132439666082558}</td>
#       <td>0.003659</td>
#       <td>10.007926</td>
#       <td>1.5</td>
#       <td>(0.3, 0.3, 0.2)</td>
#       <td>(0.1, 0.0, 0.2)</td>
#       <td>SHK</td>
#       <td>0.0</td>
#       <td>11.0</td>
#       <td>0.21</td>
#       <td>1.0</td>
#       <td>0.0</td>
#       <td>0.2</td>
#       <td>0.424264</td>
#     </tr>
#     <tr>
#       <th>EccContPrecDiff007</th>
#       <td>7</td>
#       <td>{2: 'Completed', 3: 'Completed'}</td>
#       <td>0.017183</td>
#       <td>{2: 30.4822281886772, 3: 30.488054612491805}</td>
#       <td>{2: 30.51949011892798, 3: 30.510827762781076}</td>
#       <td>0.001049</td>
#       <td>13.986663</td>
#       <td>2.5</td>
#       <td>(0.1, 0.4, 0.0)</td>
#       <td>(0.5, 0.0, 0.0)</td>
#       <td>SHK</td>
#       <td>0.0</td>
#       <td>14.0</td>
#       <td>0.08</td>
#       <td>1.5</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.412311</td>
#     </tr>
#     <tr>
#       <th>EccContPrecDiff008</th>
#       <td>8</td>
#       <td>{2: 'Completed', 3: 'Completed'}</td>
#       <td>0.018468</td>
#       <td>{2: 40.21426704175213, 3: 40.2427412095804}</td>
#       <td>{2: 40.69528814795823, 3: 40.73781477765863}</td>
#       <td>0.0</td>
#       <td>13.94</td>
#       <td>1.0</td>
#       <td>(0.3, 0.4, 0.0)</td>
#       <td>(0.0, 0.0, 0.0)</td>
#       <td>SHK</td>
#       <td>0.0</td>
#       <td>17.0</td>
#       <td>0.18</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.5</td>
#     </tr>
#   </tbody>
# </table>
