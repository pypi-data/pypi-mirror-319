# %%
# %load_ext autoreload
# %autoreload 2
import time
import multiprocessing
from pathlib import Path
import shutil
import numpy as np
import thuner.data as data
import thuner.data.dispatch as dispatch
import thuner.grid as grid
import thuner.option as option
import thuner.track as track
import thuner.analyze as analyze
import thuner.parallel as parallel
import thuner.visualize as visualize
import thuner.log as log

notebook_name = "gridrad_demo.ipynb"
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 8
#       6 import shutil
#       7 import numpy as np
# ----> 8 import thuner.data as data
#       9 import thuner.data.dispatch as dispatch
#      10 import thuner.grid as grid
#
# ModuleNotFoundError: No module named 'thuner'

# %%
# Out:
# ['/home/ewan/miniconda/envs/THUNER/lib/python310.zip',
#  '/home/ewan/miniconda/envs/THUNER/lib/python3.10',
#  '/home/ewan/miniconda/envs/THUNER/lib/python3.10/lib-dynload',
#  '',
#  '/home/ewan/.local/lib/python3.10/site-packages',
#  '/home/ewan/miniconda/envs/THUNER/lib/python3.10/site-packages',
#  '/home/ewan/Documents/THUNER/thuner']

# %%
# Parent directory for saving outputs
base_local = Path.home() / "THUNER_output"
year=2010
event_directories = data.gridrad.get_event_directories(year, base_local=base_local)
event_directory = event_directories[0]
start, end, event_start = data.gridrad.get_event_times(event_directory)
start = "2010-01-20T22:00:00"
end = "2010-01-21T02:00:00"

period = parallel.get_period(start, end)
intervals = parallel.get_time_intervals(start, end, period=period)

output_parent = base_local / f"runs/gridrad_demo"
event_start
# Out:
# '2010-01-20'

# %%
# if output_parent.exists():
# shutil.rmtree(output_parent)
options_directory = output_parent / "options"

# Create and save the dataset options
times_dict = {"start": start, "end": end}
gridrad_dict = {"event_start": event_start}
gridrad_options = data.option.GridRadSevereOptions(**times_dict, **gridrad_dict)
era5_dict = {"latitude_range": [27, 39], "longitude_range": [-102, -89]}
era5_pl_options = data.option.ERA5Options(**times_dict, **era5_dict)
era5_dict.update({"data_format": "single-levels"})
era5_sl_options = data.option.ERA5Options(**times_dict, **era5_dict)
data_options = data.option.DataOptions(
    datasets=[gridrad_options, era5_pl_options, era5_sl_options]
)
data_options.to_yaml(options_directory / "data.yml")
gridrad_options = data_options.dataset_by_name("gridrad")

# Create and save the grid_options dictionary 
grid_options = grid.GridOptions(
    name="geographic", regrid=False, altitude_spacing=None, geographic_spacing=None
)
grid_options.to_yaml(options_directory / "grid.yml")

# Create the track_options dictionary
track_options = option.default_track_options(dataset="gridrad")
# Modify the default options for gridrad. Because grids so large we now use a distinct
# global flow box for each object.
track_options.levels[1].objects[0].tracking.global_flow_margin = 70
track_options.levels[1].objects[0].tracking.unique_global_flow = False
# If testing, remove the profile and tag attributes
# track_options.levels[1].objects[0].attributes["mcs"].pop("profile")
# track_options.levels[1].objects[0].attributes["mcs"].pop("tag")
track_options.to_yaml(options_directory / "track.yml")

# Create the display_options dictionary
# visualize_options = {
#     obj: visualize.option.runtime_options(obj, save=True, style="presentation")
#     for obj in ["mcs"]
# }
visualize_options = None
# Out:
# 2024-12-11 16:23:48,846 - thuner.data.option - INFO - Generating era5 filepaths.
# 2024-12-11 16:23:48,848 - thuner.data.option - INFO - Generating era5 filepaths.
# 2024-12-11 16:23:48,851 - thuner.data.option - INFO - Generating era5 filepaths.
# 2024-12-11 16:23:48,869 - thuner.grid - WARNING - altitude_spacing not specified. Will attempt to infer frominput.
# 2024-12-11 16:23:48,871 - thuner.grid - WARNING - shape not specified. Will attempt to infer from input.

# %%
times = data.utils.generate_times(data_options.dataset_by_name("gridrad"))
args = [times, data_options.model_copy(), grid_options.copy()]
args += [track_options.model_copy(), visualize_options]
track.simultaneous_track(*args, output_directory=output_parent)
# Out:
# 2024-12-11 16:23:50,460 - thuner.track - INFO - Beginning thuner run. Saving output to /home/ewan/THUNER_output/runs/gridrad_demo.
# 2024-12-11 16:23:50,462 - thuner.track - INFO - Beginning simultaneous tracking.
# 2024-12-11 16:23:51,662 - thuner.track - INFO - Processing 2010-01-20T22:00:00.
# 2024-12-11 16:23:51,663 - thuner.data.gridrad - INFO - Updating gridrad dataset for 2010-01-20T22:00:00.
# 2024-12-11 16:23:51,664 - thuner.data.gridrad - INFO - Converting gridrad data from nexrad_3d_v4_2_20100120T220000Z.nc
# 2024-12-11 16:23:53,433 - thuner.track - INFO - Processing hierarchy level 0.
# 2024-12-11 16:23:53,434 - thuner.track - INFO - Tracking convective.
# 2024-12-11 16:24:06,629 - thuner.track - INFO - Tracking middle.
# 2024-12-11 16:24:07,008 - thuner.track - INFO - Tracking anvil.
# 2024-12-11 16:24:07,375 - thuner.track - INFO - Processing hierarchy level 1.
# 2024-12-11 16:24:07,376 - thuner.track - INFO - Tracking mcs.
# 2024-12-11 16:24:08,050 - thuner.match.match - INFO - Matching mcs objects.
# 2024-12-11 16:24:08,056 - thuner.match.match - INFO - No previous mask, or no objects in previous mask.
# 2024-12-11 16:24:08,118 - thuner.track - INFO - Processing 2010-01-20T22:10:00.
# 2024-12-11 16:24:08,121 - thuner.data.gridrad - INFO - Updating gridrad dataset for 2010-01-20T22:10:00.
# 2024-12-11 16:24:08,122 - thuner.data.gridrad - INFO - Converting gridrad data from nexrad_3d_v4_2_20100120T221000Z.nc
# 2024-12-11 16:24:09,842 - thuner.data.era5 - INFO - Updating era5_pl dataset for 2010-01-20T22:00:00.
# 2024-12-11 16:24:09,843 - thuner.data.era5 - INFO - Subsetting era5_pl data.
# 2024-12-11 16:24:12,117 - thuner.data.era5 - INFO - Updating era5_sl dataset for 2010-01-20T22:00:00.
# 2024-12-11 16:24:12,120 - thuner.data.era5 - INFO - Subsetting era5_sl data.
# 2024-12-11 16:24:12,379 - thuner.track - INFO - Processing hierarchy level 0.
# 2024-12-11 16:24:12,380 - thuner.track - INFO - Tracking convective.
# 2024-12-11 16:24:13,952 - thuner.attribute.attribute - INFO - Recording object attributes.
# 2024-12-11 16:24:13,953 - thuner.track - INFO - Tracking middle.
# 2024-12-11 16:24:14,307 - thuner.attribute.attribute - INFO - Recording object attributes.
# 2024-12-11 16:24:14,308 - thuner.track - INFO - Tracking anvil.
# 2024-12-11 16:24:14,720 - thuner.attribute.attribute - INFO - Recording object attributes.
# 2024-12-11 16:24:14,722 - thuner.track - INFO - Processing hierarchy level 1.
# 2024-12-11 16:24:14,724 - thuner.track - INFO - Tracking mcs.
# 2024-12-11 16:24:14,730 - thuner.write.mask - INFO - Writing mcs masks to /home/ewan/THUNER_output/runs/gridrad_demo/masks/mcs.zarr.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 4
#       2 args = [times, data_options.model_copy(), grid_options.copy()]
#       3 args += [track_options.model_copy(), visualize_options]
# ----> 4 track.simultaneous_track(*args, output_directory=output_parent)
#
# File ~/Documents/THUNER/thuner/track.py:240, in simultaneous_track(times, data_options, grid_options, track_options, visualize_options, output_directory)
#     238         track_level_args += [data_options, grid_options, track_options]
#     239         track_level_args += [visualize_options, output_directory]
# --> 240         track_level(*track_level_args)
#     242     previous_time = time
#     244 # Write final data to file
#     245 # write.mask.write_final(tracks, track_options, output_directory)
#
# File ~/Documents/THUNER/thuner/track.py:285, in track_level(time, level_index, tracks, input_records, data_options, grid_options, track_options, visualize_options, output_directory)
#     283 for obj in level_tracks.keys():
#     284     track_object_args = get_track_object_args(obj, level_options)
# --> 285     track_object(*track_object_args)
#     287 return level_tracks
#
# File ~/Documents/THUNER/thuner/track.py:331, in track_object(time, level_index, obj, tracks, input_records, dataset_options, grid_options, track_options, visualize_options, output_directory)
#     329 get_objects_args = [track_input_records, tracks, level_index, obj, dataset_options]
#     330 get_objects_args += [object_options, grid_options]
# --> 331 get_objects(*get_objects_args)
#     333 match.match(object_tracks, object_options, grid_options)
#     335 # Visualize the operation of the algorithm
#
# File ~/Documents/THUNER/thuner/group/group.py:36, in group(track_input_records, tracks, level_index, obj, dataset_options, object_options, grid_options)
#      34 # Store the domain boundaries associated with the consituent masks
#      35 grid = xr.Dataset(grid_dict)
# ---> 36 mask = get_connected_components(tracks, object_options)
#      38 previous_mask = copy.deepcopy(tracks[level_index][obj]["current_mask"])
#      39 tracks[level_index][obj]["previous_masks"].append(previous_mask)
#
# File ~/Documents/THUNER/thuner/group/group.py:100, in get_connected_components(tracks, object_options)
#      97 new_obj_counter = 0
#      98 for i in range(len(new_objs)):
#      99     # Require that components span all member objects
# --> 100     if not component_span(masks, list(new_objs[i])):
#     101         continue
#     102     # Require total areas of member objects are above thresholds after grouping
#
# File ~/Documents/THUNER/thuner/group/group.py:135, in component_span(masks, new_objs)
#     133 in_mask = []
#     134 for i in range(len(masks)):
# --> 135     in_mask.append(any([j in masks[i] for j in new_objs]))
#     137 return all(in_mask)
#
# File ~/Documents/THUNER/thuner/group/group.py:135, in <listcomp>(.0)
#     133 in_mask = []
#     134 for i in range(len(masks)):
# --> 135     in_mask.append(any([j in masks[i] for j in new_objs]))
#     137 return all(in_mask)
#
# KeyboardInterrupt:

# %%
# num_processes = int(0.75 * os.cpu_count())
# num_processes = os.cpu_count()
num_processes = 4
kwargs = {"initializer": parallel.initialize_process, "processes": num_processes}
with log.logging_listener(), multiprocessing.get_context("spawn").Pool(**kwargs) as pool:
    results = []
    for i, time_interval in enumerate(intervals):
        time.sleep(1)
        args = [i, time_interval, data_options.model_copy(), grid_options.copy()]
        args += [track_options.model_copy(), visualize_options]
        args += [output_parent, "gridrad"]
        args = tuple(args)
        results.append(pool.apply_async(parallel.track_interval, args))
    pool.close()
    pool.join()
    parallel.check_results(results)
# Out:
# ## You are using the Python ARM Radar Toolkit (Py-ART), an open source
# ## library for working with weather radar data. Py-ART is partly
# ## supported by the U.S. Department of Energy as part of the Atmospheric
# ## Radiation Measurement (ARM) Climate Research Facility, an Office of
# ## Science user facility.
# ##
# ## If you use this software to prepare a publication, please cite:
# ##
# ##     JJ Helmus and SM Collis, JORS 2016, doi: 10.5334/jors.119
#
#
# ## You are using the Python ARM Radar Toolkit (Py-ART), an open source
# ## library for working with weather radar data. Py-ART is partly
# ## supported by the U.S. Department of Energy as part of the Atmospheric
# ## Radiation Measurement (ARM) Climate Research Facility, an Office of
# ## Science user facility.
# ##
# ## If you use this software to prepare a publication, please cite:
# ##
# ##     JJ Helmus and SM Collis, JORS 2016, doi: 10.5334/jors.119
#
#
# ## You are using the Python ARM Radar Toolkit (Py-ART), an open source
# ## library for working with weather radar data. Py-ART is partly
# ## supported by the U.S. Department of Energy as part of the Atmospheric
# ## Radiation Measurement (ARM) Climate Research Facility, an Office of
# ## Science user facility.
# ##
# ## If you use this software to prepare a publication, please cite:
# ##
# ##     JJ Helmus and SM Collis, JORS 2016, doi: 10.5334/jors.119
#
#
# ## You are using the Python ARM Radar Toolkit (Py-ART), an open source
# ## library for working with weather radar data. Py-ART is partly
# ## supported by the U.S. Department of Energy as part of the Atmospheric
# ## Radiation Measurement (ARM) Climate Research Facility, an Office of
# ## Science user facility.
# ##
# ## If you use this software to prepare a publication, please cite:
# ##
# ##     JJ Helmus and SM Collis, JORS 2016, doi: 10.5334/jors.119
# 2024-12-11 16:24:29,179 - thuner.track - INFO - Beginning thuner run. Saving output to /home/ewan/THUNER_output/runs/gridrad_demo/interval_0.
# 2024-12-11 16:24:29,179 - thuner.track - INFO - Beginning simultaneous tracking.
# 2024-12-11 16:24:29,221 - thuner.track - INFO - Beginning thuner run. Saving output to /home/ewan/THUNER_output/runs/gridrad_demo/interval_1.
# 2024-12-11 16:24:29,223 - thuner.track - INFO - Beginning simultaneous tracking.
# 2024-12-11 16:24:29,321 - thuner.track - INFO - Beginning thuner run. Saving output to /home/ewan/THUNER_output/runs/gridrad_demo/interval_2.
# 2024-12-11 16:24:29,322 - thuner.track - INFO - Beginning simultaneous tracking.
# 2024-12-11 16:24:29,377 - thuner.track - INFO - Beginning thuner run. Saving output to /home/ewan/THUNER_output/runs/gridrad_demo/interval_3.
# 2024-12-11 16:24:29,378 - thuner.track - INFO - Beginning simultaneous tracking.
# 2024-12-11 16:24:30,275 - thuner.track - INFO - Processing 2010-01-20T22:00:00.
# 2024-12-11 16:24:30,275 - thuner.data.gridrad - INFO - Updating gridrad dataset for 2010-01-20T22:00:00.
# 2024-12-11 16:24:30,275 - thuner.data.gridrad - INFO - Converting gridrad data from nexrad_3d_v4_2_20100120T220000Z.nc
# 2024-12-11 16:24:30,357 - thuner.track - INFO - Processing 2010-01-20T23:00:00.
# 2024-12-11 16:24:30,359 - thuner.data.gridrad - INFO - Updating gridrad dataset for 2010-01-20T23:00:00.
# 2024-12-11 16:24:30,359 - thuner.data.gridrad - INFO - Converting gridrad data from nexrad_3d_v4_2_20100120T230000Z.nc
# 2024-12-11 16:24:30,498 - thuner.track - INFO - Processing 2010-01-21T00:00:00.
# 2024-12-11 16:24:30,499 - thuner.data.gridrad - INFO - Updating gridrad dataset for 2010-01-21T00:00:00.
# 2024-12-11 16:24:30,499 - thuner.data.gridrad - INFO - Converting gridrad data from nexrad_3d_v4_2_20100121T000000Z.nc
# 2024-12-11 16:24:30,560 - thuner.track - INFO - Processing 2010-01-21T01:00:00.
# 2024-12-11 16:24:30,562 - thuner.data.gridrad - INFO - Updating gridrad dataset for 2010-01-21T01:00:00.
# 2024-12-11 16:24:30,562 - thuner.data.gridrad - INFO - Converting gridrad data from nexrad_3d_v4_2_20100121T010000Z.nc
# 2024-12-11 16:24:34,751 - thuner.track - INFO - Processing hierarchy level 0.
# 2024-12-11 16:24:34,752 - thuner.track - INFO - Tracking convective.
# 2024-12-11 16:24:34,966 - thuner.track - INFO - Processing hierarchy level 0.
# 2024-12-11 16:24:34,966 - thuner.track - INFO - Tracking convective.
# 2024-12-11 16:24:35,314 - thuner.track - INFO - Processing hierarchy level 0.
# 2024-12-11 16:24:35,314 - thuner.track - INFO - Tracking convective.
# 2024-12-11 16:24:35,326 - thuner.track - INFO - Processing hierarchy level 0.
# 2024-12-11 16:24:35,327 - thuner.track - INFO - Tracking convective.
# 2024-12-11 16:24:53,410 - thuner.track - INFO - Tracking middle.
# 2024-12-11 16:24:53,765 - thuner.track - INFO - Tracking anvil.
# 2024-12-11 16:24:54,045 - thuner.track - INFO - Processing hierarchy level 1.
# 2024-12-11 16:24:54,045 - thuner.track - INFO - Tracking mcs.
# 2024-12-11 16:24:54,191 - thuner.track - INFO - Tracking middle.
# 2024-12-11 16:24:54,599 - thuner.track - INFO - Tracking anvil.
# 2024-12-11 16:24:54,808 - thuner.match.match - INFO - Matching mcs objects.
# 2024-12-11 16:24:54,812 - thuner.match.match - INFO - No previous mask, or no objects in previous mask.
# 2024-12-11 16:24:54,836 - thuner.track - INFO - Tracking middle.
# 2024-12-11 16:24:54,926 - thuner.track - INFO - Processing 2010-01-20T22:10:00.
# 2024-12-11 16:24:54,928 - thuner.data.gridrad - INFO - Updating gridrad dataset for 2010-01-20T22:10:00.
# 2024-12-11 16:24:54,928 - thuner.data.gridrad - INFO - Converting gridrad data from nexrad_3d_v4_2_20100120T221000Z.nc
# 2024-12-11 16:24:55,037 - thuner.track - INFO - Tracking middle.
# 2024-12-11 16
- thuner.match.match - INFO - Updating object record.
# 2024-12-11 16:26:03,232 - thuner.attribute.attribute - INFO - Recording object attributes.
# 2024-12-11 16:26:03,733 - thuner.attribute.attribute - INFO - Recording object attributes.
# 2024-12-11 16:26:03,734 - thuner.track - INFO - Tracking anvil.
# 2024-12-11 16:26:03,737 - thuner.write.attribute - INFO - Writing anvil attributes from 2010-01-20T22:00:00 to 2010-01-20T23:00:00, inclusive and non-inclusive, respectively.
# 2024-12-11 16:26:04,333 - thuner.match.match - INFO - Matching mcs objects.
# 2024-12-11 16:26:04,506 - thuner.write.filepath - INFO - Writing gridrad filepaths from 2010-01-21T00:00:00 to 2010-01-21T01:00:00, inclusive and non-inclusive, respectively.
# 2024-12-11 16:26:04,515 - thuner.track - INFO - Processing hierarchy level 0.
# 2024-12-11 16:26:04,515 - thuner.track - INFO - Tracking convective.
# 2024-12-11 16:26:04,516 - thuner.write.attribute - INFO - Writing convective attributes from 2010-01-21T00:00:00 to 2010-01-21T01:00:00, inclusive and non-inclusive, respectively.
# 2024-12-11 16:26:04,659 - thuner.attribute.attribute - INFO - Recording object attributes.
# 2024-12-11 16:26:04,659 - thuner.track - INFO - Processing hierarchy level 1.
# 2024-12-11 16:26:04,659 - thuner.track - INFO - Tracking mcs.
# 2024-12-11 16:26:04,665 - thuner.write.mask - INFO - Writing mcs masks to /home/ewan/THUNER_output/runs/gridrad_demo/interval_0/masks/mcs.zarr.
# 2024-12-11 16:26:04,709 - thuner.write.attribute - INFO - Writing mcs attributes from 2010-01-20T22:00:00 to 2010-01-20T23:00:00, inclusive and non-inclusive, respectively.
# 2024-12-11 16:26:04,888 - thuner.match.match - INFO - Updating object record.
# 2024-12-11 16:26:04,922 - thuner.attribute.attribute - INFO - Recording object attributes.
# 2024-12-11 16:26:04,997 - thuner.track - INFO - Processing 2010-01-21T00:00:00.
# 2024-12-11 16:26:04,999 - thuner.data.gridrad - INFO - Updating gridrad dataset for 2010-01-21T00:00:00.
# 2024-12-11 16:26:04,999 - thuner.data.gridrad - INFO - Converting gridrad data from nexrad_3d_v4_2_20100121T000000Z.nc
# 2024-12-11 16:26:06,264 - thuner.match.match - INFO - Matching mcs objects.
# 2024-12-11 16:26:06,410 - thuner.track - INFO - Processing 2010-01-21T02:00:00.
# 2024-12-11 16:26:06,410 - thuner.data.gridrad - INFO - Updating gridrad dataset for 2010-01-21T02:00:00.
# 2024-12-11 16:26:06,411 - thuner.data.gridrad - INFO - Converting gridrad data from nexrad_3d_v4_2_20100121T020000Z.nc
# 2024-12-11 16:26:06,826 - thuner.match.match - INFO - Updating object record.
# 2024-12-11 16:26:06,888 - thuner.attribute.attribute - INFO - Recording object attributes.
# 2024-12-11 16:26:08,935 - thuner.write.filepath - INFO - Writing gridrad filepaths from 2010-01-20T23:00:00 to 2010-01-21T00:00:00, inclusive and non-inclusive, respectively.
# 2024-12-11 16:26:08,959 - thuner.track - INFO - Processing hierarchy level 0.
# 2024-12-11 16:26:08,961 - thuner.track - INFO - Tracking convective.
# 2024-12-11 16:26:08,966 - thuner.write.attribute - INFO - Writing convective attributes from 2010-01-20T23:00:00 to 2010-01-21T00:00:00, inclusive and non-inclusive, respectively.
# 2024-12-11 16:26:09,169 - thuner.track - INFO - Processing 2010-01-20T23:10:00.
# 2024-12-11 16:26:09,172 - thuner.data.gridrad - INFO - Updating gridrad dataset for 2010-01-20T23:10:00.
# 2024-12-11 16:26:09,173 - thuner.data.gridrad - INFO - Converting gridrad data from nexrad_3d_v4_2_20100120T231000Z.nc
# 2024-12-11 16:26:09,623 - thuner.attribute.attribute - INFO - Recording object attributes.
# 2024-12-11 16:26:09,624 - thuner.track - INFO - Tracking middle.
# 2024-12-11 16:26:09,629 - thuner.write.attribute - INFO - Writing middle attributes from 2010-01-21T00:00:00 to 2010-01-21T01:00:00, inclusive and non-inclusive, respectively.
# 2024-12-11 16:26:10,148 - thuner.attribute.attribute - INFO - Recording object attributes.
# 2024-12-11 16:26:10,148 - thuner.track - INFO - Tracking anvil.
# 2024-12-11 16:26:10,150 - thuner.write.attribute - INFO - Writing anvil attributes from 2010-01-21T00:00:00 to 2010-01-21T01:00:00, inclusive and non-inclusive, respectively.
# 2024-12-11 16:26:10,287 - thuner.write.filepath - INFO - Writing gridrad filepaths from 2010-01-21T01:00:00 to 2010-01-21T02:00:00, inclusive and non-inclusive, respectively.
# 2024-12-11 16:26:10,299 - thuner.track - INFO - Processing hierarchy level 0.
# 2024-12-11 16:26:10,300 - thuner.track - INFO - Tracking convective.
# 2024-12-11 16:26:10,304 - thuner.write.attribute - INFO - Writing convective attributes from 2010-01-21T01:00:00 to 2010-01-21T02:00:00, inclusive and non-inclusive, respectively.
# 2024-12-11 16:26:11,415 - thuner.attribute.attribute - INFO - Recording object attributes.
# 2024-12-11 16:26:11,416 - thuner.track - INFO - Processing hierarchy level 1.
# 2024-12-11 16:26:11,416 - thuner.track - INFO - Tracking mcs.
# 2024-12-11 16:26:11,432 - thuner.write.mask - INFO - Writing mcs masks to /home/ewan/THUNER_output/runs/gridrad_demo/interval_2/masks/mcs.zarr.
# 2024-12-11 16:26:11,467 - thuner.write.attribute - INFO - Writing mcs attributes from 2010-01-21T00:00:00 to 2010-01-21T01:00:00, inclusive and non-inclusive, respectively.
# 2024-12-11 16:26:12,331 - thuner.track - INFO - Processing hierarchy level 0.
# 2024-12-11 16:26:12,334 - thuner.track - INFO - Tracking convective.
# 2024-12-11 16:26:12,625 - thuner.match.match - INFO - Matching mcs objects.
# 2024-12-11 16:26:12,948 - thuner.match.match - INFO - Updating object record.
# 2024-12-11 16:26:12,979 - thuner.attribute.attribute - INFO - Recording object attributes.
# 2024-12-11 16:26:13,075 - thuner.attribute.attribute - INFO - Recording object attributes.
# 2024-12-11 16:26:13,075 - thuner.track - INFO - Tracking middle.
# 2024-12-11 16:26:13,076 - thuner.write.attribute - INFO - Writing middle attributes from 2010-01-20T23:00:00 to 2010-01-21T00:00:00, inclusive and non-inclusive, respectively.
# 2024-12-11 16:26:13,463 - thuner.attribute.attribute - INFO - Recording object attributes.
# 2024-12-11 16:26:13,463 - thuner.track - INFO - Tracking anvil.
# 2024-12-11 16:26:13,464 - thuner.write.attribute - INFO - Writing anvil attributes from 2010-01-20T23:00:00 to 2010-01-21T00:00:00, inclusive and non-inclusive, respectively.
# 2024-12-11 16:26:13,762 - thuner.attribute.attribute - INFO - Recording object attributes.
# 2024-12-11 16:26:13,762 - thuner.track - INFO - Processing hierarchy level 1.
# 2024-12-11 16:26:13,762 - thuner.track - INFO - Tracking mcs.
# 2024-12-11 16:26:13,767 - thuner.write.mask - INFO - Writing mcs masks to /home/ewan/THUNER_output/runs/gridrad_demo/interval_1/masks/mcs.zarr.
# 2024-12-11 16:26:13,789 - thuner.write.attribute - INFO - Writing mcs attributes from 2010-01-20T23:00:00 to 2010-01-21T00:00:00, inclusive and non-inclusive, respectively.
# 2024-12-11 16:26:13,867 - thuner.track - INFO - Processing 2010-01-21T01:10:00.
# 2024-12-11 16:26:13,869 - thuner.data.gridrad - INFO - Updating gridrad dataset for 2010-01-21T01:10:00.
# 2024-12-11 16:26:13,870 - thuner.data.gridrad - INFO - Converting gridrad data from nexrad_3d_v4_2_20100121T011000Z.nc
# 2024-12-11 16:26:14,679 - thuner.match.match - INFO - Matching mcs objects.
# 2024-12-11 16:26:14,973 - thuner.attribute.attribute - INFO - Recording object attributes.
# 2024-12-11 16:26:14,974 - thuner.track - INFO - Tracking middle.
# 2024-12-11 16:26:14,996 - thuner.match.match - INFO - Updating object record.
# 2024-12-11 16:26:15,030 - thuner.attribute.attribute - INFO - Recording object attributes.
# 2024-12-11 16:26:15,032 - thuner.attribute.attribute - INFO - Recording object attributes.
# 2024-12-11 16:26:15,033 - thuner.track - INFO - Tracking middle.
# 2024-12-11 16:26:15,035 - thuner.write.attribute - INFO - Writing middle attributes from 2010-01-21T01:00:00 to 2010-01-21T02:00:00, inclusive and non-inclusive, respectively.
# 2024-12-11 16:26:15,488 - thuner.attribute.attribute - INFO - Recording object attributes.
# 2024-12-11 16:26:15,488 - thuner.track - INFO - Tracking anvil.
# 2024-12-11 16:26:15,490 - thuner.write.attribute - INFO - Writing anvil attributes from 2010-01-21T01:00:00 to 2010-01-21T02:00:00, inclusive and non-inclusive, respectively.
# 2024-12-11 16:26:15,669 - thuner.attribute.attribute - INFO - Recording object attributes.
# 2024-12-11 16:26:15,669 - thuner.track - INFO - Tracking anvil.
# 2024-12-11 16:26:16,400 - thuner.track - INFO - Processing hierarchy level 0.
# 2024-12-11 16:26:16,400 - thuner.track - INFO - Tracking convective.
# 2024-12-11 16:26:16,495 - thuner.track - INFO - Processing 2010-01-21T00:10:00.
# 2024-12-11 16:26:16,496 - thuner.data.gridrad - INFO - Updating gridrad dataset for 2010-01-21T00:10:00.
# 2024-12-11 16:26:16,496 - thuner.data.gridrad - INFO - Converting gridrad data from nexrad_3d_v4_2_20100121T001000Z.nc
# 2024-12-11 16:26:16,530 - thuner.attribute.attribute - INFO - Recording object attributes.
# 2024-12-11 16:26:16,531 - thuner.track - INFO - Processing hierarchy level 1.
# 2024-12-11 16:26:16,531 - thuner.track - INFO - Tracking mcs.
# 2024-12-11 16:26:16,542 - thuner.write.mask - INFO - Writing mcs masks to /home/ewan/THUNER_output/runs/gridrad_demo/interval_3/masks/mcs.zarr.
# 2024-12-11 16:26:16,583 - thuner.write.attribute - INFO - Writing mcs attributes from 2010-01-21T01:00:00 to 2010-01-21T02:00:00, inclusive and non-inclusive, respectively.
# 2024-12-11 16:26:16,705 - thuner.attribute.attribute - INFO - Recording object attributes.
# 2024-12-11 16:26:16,706 - thuner.track - INFO - Processing hierarchy level 1.
# 2024-12-11 16:26:16,706 - thuner.track - INFO - Tracking mcs.
# 2024-12-11 16:26:16,713 - thuner.write.mask - INFO - Writing mcs masks to /home/ewan/THUNER_output/runs/gridrad_demo/interval_0/masks/mcs.zarr.
# 2024-12-11 16:26:17,784 - thuner.match.match - INFO - Matching mcs objects.
# 2024-12-11 16:26:18,060 - thuner.match.match - INFO - Matching mcs objects.
# 2024-12-11 16:26:18,283 - thuner.match.match - INFO - Updating object record.
# 2024-12-11 16:26:18,317 - thuner.attribute.attribute - INFO - Recording object attributes.
# /home/ewan/miniconda3/envs/THUNER/lib/python3.10/site-packages/numpy/lib/_function_base_impl.py:2480: RuntimeWarning: invalid value encountered in <lambda> (vectorized)
#   outputs = ufunc(*inputs)
# 2024-12-11 16:26:18,531 - thuner.match.match - INFO - Updating object record.
# 2024-12-11 16:26:18,549 - thuner.attribute.attribute - INFO - Recording object attributes.
# 2024-12-11 16:26:18,890 - thuner.track - INFO - Processing hierarchy level 0.
# 2024-12-11 16:26:18,891 - thuner.track - INFO - Tracking convective.
# 2024-12-11 16:26:18,916 - thuner.write.attribute - INFO - Writing convective attributes from 2010-01-21T02:00:00 to 2010-01-21T03:00:00, inclusive and non-inclusive, respectively.
# 2024-12-11 16:26:18,917 - thuner.write.attribute - INFO - Writing middle attributes from 2010-01-21T02:00:00 to 2010-01-21T03:00:00, inclusive and non-inclusive, respectively.
# 2024-12-11 16:26:18,917 - thuner.write.attribute - INFO - Writing anvil attributes from 2010-01-21T02:00:00 to 2010-01-21T03:00:00, inclusive and non-inclusive, respectively.
# 2024-12-11 16:26:18,918 - thuner.write.attribute - INFO - Writing mcs attributes from 2010-01-21T02:00:00 to 2010-01-21T03:00:00, inclusive and non-inclusive, respectively.
# 2024-12-11 16:26:18,997 - thuner.write.filepath - INFO - Writing gridrad filepaths from 2010-01-21T02:00:00 to 2010-01-21T03:00:00, inclusive and non-inclusive, respectively.
# 2024-12-11 16:26:18,998 - thuner.write.attribute - INFO - Aggregating attribute files.
# 2024-12-11 16:26:19,277 - thuner.write.filepath - INFO - Aggregating filepath records.
# /home/ewan/Documents/THUNER/thuner/write/attribute.py:194: FutureWarning: The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#   df = pd.concat(df_list, sort=False)
# 2024-12-11 16:26:19,411 - thuner.write.attribute - INFO - Writing convective attributes from 2010-01-20T23:00:00 to 2010-01-21T00:00:00, inclusive and non-inclusive, respectively.
# 2024-12-11 16:26:19,411 - thuner.write.attribute - INFO - Writing middle attributes from 2010-01-20T23:00:00 to 2010-01-21T00:00:00, inclusive and non-inclusive, respectively.
# 2024-12-11 16:26:19,412 - thuner.write.attribute - INFO - Writing anvil attributes from 2010-01-20T23:00:00 to 2010-01-21T00:00:00, inclusive and non-inclusive, respectively.
# 2024-12-11 16:26:19,413 - thuner.write.attribute - INFO - Writing mcs attributes from 2010-01-20T23:00:00 to 2010-01-21T00:00:00, inclusive and non-inclusive, respectively.
# 2024-12-11 16:26:19,517 - thuner.write.filepath - INFO - Writing gridrad filepaths from 2010-01-20T23:00:00 to 2010-01-21T00:00:00, inclusive and non-inclusive, respectively.
# 2024-12-11 16:26:19,523 - thuner.write.attribute - INFO - Aggregating attribute files.
# 2024-12-11 16:26:19,768 - thuner.write.filepath - INFO - Aggregating filepath records.
# 2024-12-11 16:26:19,867 - thuner.attribute.attribute - INFO - Recording object attributes.
# 2024-12-11 16:26:19,867 - thuner.track - INFO - Tracking middle.
# 2024-12-11 16:26:20,100 - thuner.attribute.attribute - INFO - Recording object attributes.
# 2024-12-11 16:26:20,100 - thuner.track - INFO - Tracking anvil.
# 2024-12-11 16:26:20,344 - thuner.attribute.attribute - INFO - Recording object attributes.
# 2024-12-11 16:26:20,344 - thuner.track - INFO - Processing hierarchy level 1.
# 2024-12-11 16:26:20,344 - thuner.track - INFO - Tracking mcs.
# 2024-12-11 16:26:20,349 - thuner.write.mask - INFO - Writing mcs masks to /home/ewan/THUNER_output/runs/gridrad_demo/interval_2/masks/mcs.zarr.
# 2024-12-11 16:26:20,818 - thuner.match.match - INFO - Matching mcs objects.
# 2024-12-11 16:26:21,074 - thuner.match.match - INFO - Updating object record.
# 2024-12-11 16:26:21,108 - thuner.attribute.attribute - INFO - Recording object attributes.
# 2024-12-11 16:26:21,295 - thuner.attribute.attribute - INFO - Recording object attributes.
# 2024-12-11 16:26:21,296 - thuner.track - INFO - Tracking middle.
# 2024-12-11 16:26:21,493 - thuner.attribute.attribute - INFO - Recording object attributes.
# 2024-12-11 16:26:21,493 - thuner.track - INFO - Tracking anvil.
# 2024-12-11 16:26:21,829 - thuner.attribute.attribute - INFO - Recording object attributes.
# 2024-12-11 16:26:21,829 - thuner.track - INFO - Processing hierarchy level 1.
# 2024-12-11 16:26:21,829 - thuner.track - INFO - Tracking mcs.
# 2024-12-11 16:26:21,834 - thuner.write.mask - INFO - Writing mcs masks to /home/ewan/THUNER_output/runs/gridrad_demo/interval_1/masks/mcs.zarr.
# 2024-12-11 16:26:21,958 - thuner.write.attribute - INFO - Writing convective attributes from 2010-01-21T01:00:00 to 2010-01-21T02:00:00, inclusive and non-inclusive, respectively.
# 2024-12-11 16:26:21,959 - thuner.write.attribute - INFO - Writing middle attributes from 2010-01-21T01:00:00 to 2010-01-21T02:00:00, inclusive and non-inclusive, respectively.
# 2024-12-11 16:26:21,960 - thuner.write.attribute - INFO - Writing anvil attributes from 2010-01-21T01:00:00 to 2010-01-21T02:00:00, inclusive and non-inclusive, respectively.
# 2024-12-11 16:26:21,961 - thuner.write.attribute - INFO - Writing mcs attributes from 2010-01-21T01:00:00 to 2010-01-21T02:00:00, inclusive and non-inclusive, respectively.
# 2024-12-11 16:26:22,071 - thuner.write.filepath - INFO - Writing gridrad filepaths from 2010-01-21T01:00:00 to 2010-01-21T02:00:00, inclusive and non-inclusive, respectively.
# 2024-12-11 16:26:22,075 - thuner.write.attribute - INFO - Aggregating attribute files.
# 2024-12-11 16:26:22,422 - thuner.write.filepath - INFO - Aggregating filepath records.
# 2024-12-11 16:26:22,464 - thuner.match.match - INFO - Matching mcs objects.
# 2024-12-11 16:26:22,750 - thuner.match.match - INFO - Updating object record.
# 2024-12-11 16:26:22,767 - thuner.attribute.attribute - INFO - Recording object attributes.
# 2024-12-11 16:26:23,374 - thuner.write.attribute - INFO - Writing convective attributes from 2010-01-21T00:00:00 to 2010-01-21T01:00:00, inclusive and non-inclusive, respectively.
# 2024-12-11 16:26:23,375 - thuner.write.attribute - INFO - Writing middle attributes from 2010-01-21T00:00:00 to 2010-01-21T01:00:00, inclusive and non-inclusive, respectively.
# 2024-12-11 16:26:23,376 - thuner.write.attribute - INFO - Writing anvil attributes from 2010-01-21T00:00:00 to 2010-01-21T01:00:00, inclusive and non-inclusive, respectively.
# 2024-12-11 16:26:23,376 - thuner.write.attribute - INFO - Writing mcs attributes from 2010-01-21T00:00:00 to 2010-01-21T01:00:00, inclusive and non-inclusive, respectively.
# 2024-12-11 16:26:23,547 - thuner.write.filepath - INFO - Writing gridrad filepaths from 2010-01-21T00:00:00 to 2010-01-21T01:00:00, inclusive and non-inclusive, respectively.
# 2024-12-11 16:26:23,550 - thuner.write.attribute - INFO - Aggregating attribute files.
# 2024-12-11 16:26:23,866 - thuner.write.filepath - INFO - Aggregating filepath records.

# %%
parallel.stitch_run(output_parent, intervals, cleanup=True)
# Out:
# 2024-12-11 16:45:17,791 - thuner.parallel - INFO - Stitching all attribute, mask and record files.
# 2024-12-11 16:45:17,807 - thuner.grid - WARNING - altitude_spacing not specified. Will attempt to infer frominput.
# 2024-12-11 16:45:17,809 - thuner.grid - WARNING - shape not specified. Will attempt to infer from input.
# 2024-12-11 16:45:21,423 - thuner.parallel - INFO - Stitching record files.
# 2024-12-11 16:45:21,456 - thuner.parallel - INFO - Stitching attribute files.
# 2024-12-11 16:45:23,049 - thuner.parallel - INFO - Stitching mask files.

# %%
analysis_options = analyze.mcs.AnalysisOptions()
analyze.mcs.process_velocities(output_parent, profile_dataset=None)
analyze.mcs.quality_control(output_parent, analysis_options)
# analyze.mcs.classify_all(output_parent, analysis_options)
# Out:
# 2024-12-11 16:45:26,116 - thuner.grid - WARNING - altitude_spacing not specified. Will attempt to infer frominput.
# 2024-12-11 16:45:26,117 - thuner.grid - WARNING - shape not specified. Will attempt to infer from input.
# 2024-12-11 16:45:26,299 - thuner.grid - WARNING - altitude_spacing not specified. Will attempt to infer frominput.
# 2024-12-11 16:45:26,300 - thuner.grid - WARNING - shape not specified. Will attempt to infer from input.
#                                   convective_contained  anvil_contained  \
# time                universal_id
# 2010-01-20 22:00:00 1                             True            False
#                     2                             True             True
#                     3                             True             True
#                     4                             True             True
#                     5                             True             True
# ...                                                ...              ...
# 2010-01-21 01:50:00 11                            True             True
#                     14                            True             True
#                     15                           False            False
#                     27                            True             True
#                     30                            True             True
#
#                                   initially_contained  velocity  area  offset  \
# time                universal_id
# 2010-01-20 22:00:00 1                           False      True  True    True
#                     2                            True      True  True    True
#                     3                            True      True  True   False
#                     4                            True      True  True    True
#                     5                            True      True  True    True
# ...                                               ...       ...   ...     ...
# 2010-01-21 01:50:00 11                           True      True  True    True
#                     14                           True      True  True   False
#                     15                           True      True  True    True
#                     27                           True      True  True   False
#                     30                           True      True  True   False
#
#                                   major_axis  axis_ratio  duration  parents  \
# time                universal_id
# 2010-01-20 22:00:00 1                   True        True      True    False
#                     2                   True        True     False    False
#                     3                   True        True     False    False
#                     4                   True       False      True     True
#                     5                   True        True     False    False
# ...                                      ...         ...       ...      ...
# 2010-01-21 01:50:00 11                  True        True      True     True
#                     14                  True        True      True     True
#                     15                 False       False      True     True
#                     27                  True       False      True    False
#                     30                  True       False     False    False
#
#                                   children
# time                universal_id
# 2010-01-20 22:00:00 1                 True
#                     2                 True
#                     3                False
#                     4                 True
#                     5                 True
# ...                                    ...
# 2010-01-21 01:50:00 11                True
#                     14               False
#                     15                True
#                     27               False
#                     30               False
#
# [216 rows x 11 columns]

# %%
figure_name = f"mcs_gridrad_{event_start.replace('-', '')}"
figure_options = visualize.option.horizontal_attribute_options(
    figure_name, style="presentation", attributes=["velocity", "offset"]
)
start_time = np.datetime64(start)
end_time = np.datetime64(end)
args = [output_parent, start_time, end_time, figure_options]
args_dict = {"parallel_figure": True, "dt": 7200, "by_date": False, "num_processes": 4}
visualize.attribute.mcs_series(*args, **args_dict)
# Out:
# 2024-12-11 16:45:28,429 - thuner.grid - WARNING - altitude_spacing not specified. Will attempt to infer frominput.
# 2024-12-11 16:45:28,430 - thuner.grid - WARNING - shape not specified. Will attempt to infer from input.
# 2024-12-11 16:45:28,716 - thuner.visualize.attribute - INFO - Visualizing MCS at time 2010-01-20T22:00:00.000000000.
# 2024-12-11 16:45:30,359 - thuner.grid - WARNING - altitude_spacing not specified. Will attempt to infer frominput.
# 2024-12-11 16:45:30,360 - thuner.grid - WARNING - shape not specified. Will attempt to infer from input.
# 2024-12-11 16:45:33,629 - thuner.visualize.attribute - INFO - Saving mcs_gridrad_20100120 figure for 2010-01-20T22:00:00.000000000.
# ## You are using the Python ARM Radar Toolkit (Py-ART), an open source
# ## library for working with weather radar data. Py-ART is partly
# ## supported by the U.S. Department of Energy as part of the Atmospheric
# ## Radiation Measurement (ARM) Climate Research Facility, an Office of
# ## Science user facility.
# ##
# ## If you use this software to prepare a publication, please cite:
# ##
# ##     JJ Helmus and SM Collis, JORS 2016, doi: 10.5334/jors.119
#
#
# ## You are using the Python ARM Radar Toolkit (Py-ART), an open source
# ## library for working with weather radar data. Py-ART is partly
# ## supported by the U.S. Department of Energy as part of the Atmospheric
# ## Radiation Measurement (ARM) Climate Research Facility, an Office of
# ## Science user facility.
# ##
# ## If you use this software to prepare a publication, please cite:
# ##
# ##     JJ Helmus and SM Collis, JORS 2016, doi: 10.5334/jors.119
#
#
# ## You are using the Python ARM Radar Toolkit (Py-ART), an open source
# ## library for working with weather radar data. Py-ART is partly
# ## supported by the U.S. Department of Energy as part of the Atmospheric
# ## Radiation Measurement (ARM) Climate Research Facility, an Office of
# ## Science user facility.
# ##
# ## If you use this software to prepare a publication, please cite:
# ##
# ##     JJ Helmus and SM Collis, JORS 2016, doi: 10.5334/jors.119
#
#
# ## You are using the Python ARM Radar Toolkit (Py-ART), an open source
# ## library for working with weather radar data. Py-ART is partly
# ## supported by the U.S. Department of Energy as part of the Atmospheric
# ## Radiation Measurement (ARM) Climate Research Facility, an Office of
# ## Science user facility.
# ##
# ## If you use this software to prepare a publication, please cite:
# ##
# ##     JJ Helmus and SM Collis, JORS 2016, doi: 10.5334/jors.119
# 2024-12-11 16:45:44,077 - thuner.visualize.attribute - INFO - Visualizing MCS at time 2010-01-20T22:10:00.000000000.
# 2024-12-11 16:45:44,155 - thuner.visualize.attribute - INFO - Visualizing MCS at time 2010-01-20T22:20:00.000000000.
# 2024-12-11 16:45:44,397 - thuner.visualize.attribute - INFO - Visualizing MCS at time 2010-01-20T22:30:00.000000000.
# 2024-12-11 16:45:46,333 - thuner.visualize.attribute - INFO - Visualizing MCS at time 2010-01-20T22:40:00.000000000.
# 2024-12-11 16:45:47,801 - thuner.grid - WARNING - altitude_spacing not specified. Will attempt to infer frominput.
# 2024-12-11 16:45:47,801 - thuner.grid - WARNING - shape not specified. Will attempt to infer from input.
# 2024-12-11 16:45:47,843 - thuner.grid - WARNING - altitude_spacing not specified. Will attempt to infer frominput.
# 2024-12-11 16:45:47,843 - thuner.grid - WARNING - shape not specified. Will attempt to infer from input.
# 2024-12-11 16:45:48,322 - thuner.grid - WARNING - altitude_spacing not specified. Will attempt to infer frominput.
# 2024-12-11 16:45:48,323 - thuner.grid - WARNING - shape not specified. Will attempt to infer from input.
# 2024-12-11 16:45:51,743 - thuner.grid - WARNING - altitude_spacing not specified. Will attempt to infer frominput.
# 2024-12-11 16:45:51,744 - thuner.grid - WARNING - shape not specified. Will attempt to infer from input.
# 2024-12-11 16:45:55,093 - thuner.visualize.attribute - INFO - Saving mcs_gridrad_20100120 figure for 2010-01-20T22:10:00.000000000.
# 2024-12-11 16:45:55,236 - thuner.visualize.attribute - INFO - Saving mcs_gridrad_20100120 figure for 2010-01-20T22:20:00.000000000.
# 2024-12-11 16:45:55,345 - thuner.visualize.attribute - INFO - Saving mcs_gridrad_20100120 figure for 2010-01-20T22:30:00.000000000.
# 2024-12-11 16:46:00,663 - thuner.visualize.attribute - INFO - Saving mcs_gridrad_20100120 figure for 2010-01-20T22:40:00.000000000.
# 2024-12-11 16:46:06,928 - thuner.visualize.attribute - INFO - Visualizing MCS at time 2010-01-20T22:50:00.000000000.
# 2024-12-11 16:46:07,141 - thuner.visualize.attribute - INFO - Visualizing MCS at time 2010-01-20T23:00:00.000000000.
# 2024-12-11 16:46:07,252 - thuner.visualize.attribute - INFO - Visualizing MCS at time 2010-01-20T23:10:00.000000000.
# 2024-12-11 16:46:11,803 - thuner.grid - WARNING - altitude_spacing not specified. Will attempt to infer frominput.
# 2024-12-11 16:46:11,806 - thuner.grid - WARNING - shape not specified. Will attempt to infer from input.
# 2024-12-11 16:46:11,814 - thuner.grid - WARNING - altitude_spacing not specified. Will attempt to infer frominput.
# 2024-12-11 16:46:11,815 - thuner.grid - WARNING - shape not specified. Will attempt to infer from input.
# 2024-12-11 16:46:11,842 - thuner.grid - WARNING - altitude_spacing not specified. Will attempt to infer frominput.
# 2024-12-11 16:46:11,842 - thuner.grid - WARNING - shape not specified. Will attempt to infer from input.
# 2024-12-11 16:46:12,977 - thuner.visualize.attribute - INFO - Visualizing MCS at time 2010-01-20T23:20:00.000000000.
# 2024-12-11 16:46:17,547 - thuner.grid - WARNING - altitude_spacing not specified. Will attempt to infer frominput.
# 2024-12-11 16:46:17,548 - thuner.grid - WARNING - shape not specified. Will attempt to infer from input.
# 2024-12-11 16:46:22,295 - thuner.visualize.attribute - INFO - Saving mcs_gridrad_20100120 figure for 2010-01-20T23:00:00.000000000.
# 2024-12-11 16:46:22,474 - thuner.visualize.attribute - INFO - Saving mcs_gridrad_20100120 figure for 2010-01-20T22:50:00.000000000.
# 2024-12-11 16:46:22,686 - thuner.visualize.attribute - INFO - Saving mcs_gridrad_20100120 figure for 2010-01-20T23:10:00.000000000.
# 2024-12-11 16:46:26,551 - thuner.visualize.attribute - INFO - Saving mcs_gridrad_20100120 figure for 2010-01-20T23:20:00.000000000.
# 2024-12-11 16:46:32,180 - thuner.visualize.attribute - INFO - Visualizing MCS at time 2010-01-20T23:30:00.000000000.
# 2024-12-11 16:46:32,535 - thuner.visualize.attribute - INFO - Visualizing MCS at time 2010-01-20T23:40:00.000000000.
# 2024-12-11 16:46:33,747 - thuner.visualize.attribute - INFO - Visualizing MCS at time 2010-01-20T23:50:00.000000000.
# 2024-12-11 16:46:34,867 - thuner.grid - WARNING - altitude_spacing not specified. Will attempt to infer frominput.
# 2024-12-11 16:46:34,867 - thuner.grid - WARNING - shape not specified. Will attempt to infer from input.
# 2024-12-11 16:46:35,274 - thuner.grid - WARNING - altitude_spacing not specified. Will attempt to infer frominput.
# 2024-12-11 16:46:35,274 - thuner.grid - WARNING - shape not specified. Will attempt to infer from input.
# 2024-12-11 16:46:36,098 - thuner.visualize.attribute - INFO - Visualizing MCS at time 2010-01-21T00:00:00.000000000.
# 2024-12-11 16:46:36,535 - thuner.grid - WARNING - altitude_spacing not specified. Will attempt to infer frominput.
# 2024-12-11 16:46:36,535 - thuner.grid - WARNING - shape not specified. Will attempt to infer from input.
# 2024-12-11 16:46:39,508 - thuner.grid - WARNING - altitude_spacing not specified. Will attempt to infer frominput.
# 2024-12-11 16:46:39,508 - thuner.grid - WARNING - shape not specified. Will attempt to infer from input.
# 2024-12-11 16:46:41,791 - thuner.visualize.attribute - INFO - Saving mcs_gridrad_20100120 figure for 2010-01-20T23:50:00.000000000.
# 2024-12-11 16:46:42,224 - thuner.visualize.attribute - INFO - Saving mcs_gridrad_20100120 figure for 2010-01-20T23:30:00.000000000.
# 2024-12-11 16:46:43,117 - thuner.visualize.attribute - INFO - Saving mcs_gridrad_20100120 figure for 2010-01-20T23:40:00.000000000.
# 2024-12-11 16:46:45,313 - thuner.visualize.attribute - INFO - Saving mcs_gridrad_20100120 figure for 2010-01-21T00:00:00.000000000.
# 2024-12-11 16:46:48,636 - thuner.visualize.attribute - INFO - Visualizing MCS at time 2010-01-21T00:10:00.000000000.
# 2024-12-11 16:46:50,558 - thuner.grid - WARNING - altitude_spacing not specified. Will attempt to infer frominput.
# 2024-12-11 16:46:50,558 - thuner.grid - WARNING - shape not specified. Will attempt to infer from input.
# 2024-12-11 16:46:50,926 - thuner.visualize.attribute - INFO - Visualizing MCS at time 2010-01-21T00:20:00.000000000.
# 2024-12-11 16:46:51,459 - thuner.visualize.attribute - INFO - Visualizing MCS at time 2010-01-21T00:30:00.000000000.
# 2024-12-11 16:46:52,048 - thuner.visualize.attribute - INFO - Visualizing MCS at time 2010-01-21T00:40:00.000000000.
# 2024-12-11 16:46:54,552 - thuner.grid - WARNING - altitude_spacing not specified. Will attempt to infer frominput.
# 2024-12-11 16:46:54,552 - thuner.grid - WARNING - shape not specified. Will attempt to infer from input.
# 2024-12-11 16:46:54,573 - thuner.grid - WARNING - altitude_spacing not specified. Will attempt to infer frominput.
# 2024-12-11 16:46:54,573 - thuner.grid - WARNING - shape not specified. Will attempt to infer from input.
# 2024-12-11 16:46:54,826 - thuner.grid - WARNING - altitude_spacing not specified. Will attempt to infer frominput.
# 2024-12-11 16:46:54,827 - thuner.grid - WARNING - shape not specified. Will attempt to infer from input.
# 2024-12-11 16:46:56,964 - thuner.visualize.attribute - INFO - Saving mcs_gridrad_20100120 figure for 2010-01-21T00:10:00.000000000.
# 2024-12-11 16:47:01,610 - thuner.visualize.attribute - INFO - Saving mcs_gridrad_20100120 figure for 2010-01-21T00:30:00.000000000.
# 2024-12-11 16:47:01,626 - thuner.visualize.attribute - INFO - Saving mcs_gridrad_20100120 figure for 2010-01-21T00:40:00.000000000.
# 2024-12-11 16:47:02,338 - thuner.visualize.attribute - INFO - Saving mcs_gridrad_20100120 figure for 2010-01-21T00:20:00.000000000.
# 2024-12-11 16:47:06,687 - thuner.visualize.attribute - INFO - Visualizing MCS at time 2010-01-21T00:50:00.000000000.
# 2024-12-11 16:47:08,757 - thuner.grid - WARNING - altitude_spacing not specified. Will attempt to infer frominput.
# 2024-12-11 16:47:08,757 - thuner.grid - WARNING - shape not specified. Will attempt to infer from input.
# 2024-12-11 16:47:09,260 - thuner.visualize.attribute - INFO - Visualizing MCS at time 2010-01-21T01:00:00.000000000.
# 2024-12-11 16:47:10,029 - thuner.visualize.attribute - INFO - Visualizing MCS at time 2010-01-21T01:10:00.000000000.
# 2024-12-11 16:47:11,476 - thuner.visualize.attribute - INFO - Visualizing MCS at time 2010-01-21T01:20:00.000000000.
# 2024-12-11 16:47:12,286 - thuner.grid - WARNING - altitude_spacing not specified. Will attempt to infer frominput.
# 2024-12-11 16:47:12,286 - thuner.grid - WARNING - shape not specified. Will attempt to infer from input.
# 2024-12-11 16:47:13,151 - thuner.grid - WARNING - altitude_spacing not specified. Will attempt to infer frominput.
# 2024-12-11 16:47:13,152 - thuner.grid - WARNING - shape not specified. Will attempt to infer from input.
# 2024-12-11 16:47:15,105 - thuner.grid - WARNING - altitude_spacing not specified. Will attempt to infer frominput.
# 2024-12-11 16:47:15,106 - thuner.grid - WARNING - shape not specified. Will attempt to infer from input.
# 2024-12-11 16:47:16,535 - thuner.visualize.attribute - INFO - Saving mcs_gridrad_20100120 figure for 2010-01-21T00:50:00.000000000.
# /home/ewan/miniconda3/envs/THUNER/lib/python3.10/site-packages/numpy/lib/_function_base_impl.py:2480: RuntimeWarning: invalid value encountered in <lambda> (vectorized)
#   outputs = ufunc(*inputs)
# 2024-12-11 16:47:20,446 - thuner.visualize.attribute - INFO - Saving mcs_gridrad_20100120 figure for 2010-01-21T01:00:00.000000000.
# 2024-12-11 16:47:20,463 - thuner.visualize.attribute - INFO - Saving mcs_gridrad_20100120 figure for 2010-01-21T01:10:00.000000000.
# 2024-12-11 16:47:21,560 - thuner.visualize.attribute - INFO - Saving mcs_gridrad_20100120 figure for 2010-01-21T01:20:00.000000000.
# 2024-12-11 16:47:26,278 - thuner.visualize.attribute - INFO - Visualizing MCS at time 2010-01-21T01:30:00.000000000.
# 2024-12-11 16:47:27,994 - thuner.visualize.attribute - INFO - Visualizing MCS at time 2010-01-21T01:40:00.000000000.
# 2024-12-11 16:47:28,025 - thuner.visualize.attribute - INFO - Visualizing MCS at time 2010-01-21T01:50:00.000000000.
# 2024-12-11 16:47:28,322 - thuner.grid - WARNING - altitude_spacing not specified. Will attempt to infer frominput.
# 2024-12-11 16:47:28,322 - thuner.grid - WARNING - shape not specified. Will attempt to infer from input.
# 2024-12-11 16:47:30,730 - thuner.grid - WARNING - altitude_spacing not specified. Will attempt to infer frominput.
# 2024-12-11 16:47:30,730 - thuner.grid - WARNING - shape not specified. Will attempt to infer from input.
# 2024-12-11 16:47:30,834 - thuner.grid - WARNING - altitude_spacing not specified. Will attempt to infer frominput.
# 2024-12-11 16:47:30,834 - thuner.grid - WARNING - shape not specified. Will attempt to infer from input.
# 2024-12-11 16:47:33,369 - thuner.visualize.attribute - INFO - Saving mcs_gridrad_20100120 figure for 2010-01-21T01:30:00.000000000.
# /home/ewan/miniconda3/envs/THUNER/lib/python3.10/site-packages/numpy/lib/_function_base_impl.py:2480: RuntimeWarning: invalid value encountered in <lambda> (vectorized)
#   outputs = ufunc(*inputs)
# 2024-12-11 16:47:34,920 - thuner.visualize.attribute - INFO - Saving mcs_gridrad_20100120 figure for 2010-01-21T01:50:00.000000000.
# 2024-12-11 16:47:35,727 - thuner.visualize.attribute - INFO - Saving mcs_gridrad_20100120 figure for 2010-01-21T01:40:00.000000000.
# 2024-12-11 16:47:41,696 - thuner.visualize.visualize - INFO - Animating mcs_gridrad_20100120 figures for mcs objects.
# 2024-12-11 16:47:41,707 - thuner.visualize.visualize - INFO - Saving animation to /home/ewan/THUNER_output/runs/gridrad_demo/visualize/mcs_gridrad_20100120.gif.
