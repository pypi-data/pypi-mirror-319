# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
from pathlib import Path
import shutil
import numpy as np
import thuner.data as data
import thuner.data.dispatch as dispatch
import thuner.grid as grid
import thuner.track as track
import thuner.option as option
import thuner.visualize as visualize
import thuner.analyze as analyze
import thuner.option as option
import thuner.attribute as attribute
import thuner.utils as utils

notebook_name = "cpol_demo.ipynb"
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import thuner
# Out:
# Welcome to the Thunderstorm Event Reconnaissance (THUNER) package v0.0.2!
# THUNER is a flexible toolkit for performing multi-feature detection, tracking, tagging
# and analysis of events within meteorological datasets. The intended application is to
# convective weather events. If you use this package in your research, consider citing
# the following papers;
#
# Short et al. (2023), MWR, doi: 10.1175/MWR-D-22-0146.1
# Raut et al. (2021), JAMC, doi: 10.1175/JAMC-D-20-0119.1
# Fridlind et al. (2019), AMT, doi: 10.5194/amt-12-2979-2019
# Dixon and Wiener (1993), JTECH, doi: 10.1175/1520-0426(1993)010<0785:TTITAA>2.0.CO;2
# Leese et al. (1971), JAMC, doi: 10.1175/1520-0450(1971)010<0118:AATFOC>2.0.CO;2
#
# Reading configuration file.

# %%
# Parent directory for saving outputs
base_local = Path.home() / "THUNER_output"
start = "2005-11-13T18:00:00"
end = "2005-11-13T20:00:00"

output_directory = base_local / "runs/cpol/cpol_demo_geographic"

if output_directory.exists():
    shutil.rmtree(output_directory)

output_directory.mkdir(parents=True, exist_ok=True)
options_directory = output_directory / "options"
options_directory.mkdir(parents=True, exist_ok=True)

times_dict = {"start": start, "end": end}
cpol_options = data.option.CPOLOptions(**times_dict)
era5_dict = {"latitude_range": [-14, -10], "longitude_range": [129, 133]}
era5_pl_options = data.option.ERA5Options(**times_dict, **era5_dict)
era5_dict.update({"data_format": "single-levels"})
era5_sl_options = data.option.ERA5Options(**times_dict, **era5_dict)
data_options = data.option.DataOptions(
    datasets=[cpol_options, era5_pl_options, era5_sl_options]
)
data_options.to_yaml(options_directory / "data.yml")

# altitude = list(np.arange(0, 20e3 + 500, 500))
# altitude = [float(alt) for alt in altitude]
# grid_options = grid.create_options(name="geographic", altitude=altitude)
# grid.check_options(grid_options)
# grid.save_grid_options(grid_options, options_directory)

grid_options = grid.GridOptions()
grid_options.to_yaml(options_directory / "grid.yml")

# Create the track_options dictionary
track_options = option.default_track_options(dataset="cpol")
track_options.to_yaml(options_directory / "track.yml")

# Create the display_options dictionary
visualize_options = {
    obj: visualize.option.runtime_options(obj, save=True, style="presentation")
    for obj in ["mcs"]
}
visualize_options["middle_echo"] = visualize.option.runtime_options(
    "middle_echo", save=True, style="presentation", figure_types=["mask"]
)
# visualize.option.save_display_options(visualize_options, options_directory)
visualize_options = None
# Out:
# 2024-12-11 16:11:30,731 - thuner.data.option - INFO - Generating cpol filepaths.
# 2024-12-11 16:11:30,733 - thuner.data.option - INFO - Generating era5 filepaths.
# 2024-12-11 16:11:30,736 - thuner.data.option - INFO - Generating era5 filepaths.
# 2024-12-11 16:11:30,750 - thuner.grid - WARNING - altitude not specified. Using default altitudes.
# 2024-12-11 16:11:30,751 - thuner.grid - WARNING - shape not specified. Will attempt to infer from input.

# %%
times = data.utils.generate_times(data_options.dataset_by_name("cpol"))
tracks = track.simultaneous_track(
    times,
    data_options,
    grid_options,
    track_options,
    visualize_options,
    output_directory=output_directory
)
# Out:
# 2024-12-11 16:11:33,092 - thuner.track - INFO - Beginning thuner run. Saving output to /home/ewan/THUNER_output/runs/cpol/cpol_demo_geographic.
# 2024-12-11 16:11:33,094 - thuner.track - INFO - Beginning simultaneous tracking.
# 2024-12-11 16:11:34,030 - thuner.track - INFO - Processing 2005-11-13T18:00:08.
# 2024-12-11 16:11:34,031 - thuner.data.aura - INFO - Updating cpol dataset for 2005-11-13T18:00:08.
# 2024-12-11 16:11:34,032 - thuner.data.aura - INFO - Converting cpol data from twp10cpolgrid150.b2.20051113.180000.nc
# 2024-12-11 16:11:34,075 - thuner.data.aura - INFO - Creating new geographic grid with spacing 0.025 m, 0.025 m.
# 2024-12-11 16:11:36,779 - thuner.track - INFO - Processing hierarchy level 0.
# 2024-12-11 16:11:36,780 - thuner.track - INFO - Tracking convective.
# 2024-12-11 16:11:47,509 - thuner.track - INFO - Tracking middle.
# 2024-12-11 16:11:47,513 - thuner.track - INFO - Tracking anvil.
# 2024-12-11 16:11:47,516 - thuner.track - INFO - Processing hierarchy level 1.
# 2024-12-11 16:11:47,518 - thuner.track - INFO - Tracking mcs.
# 2024-12-11 16:11:47,541 - thuner.match.match - INFO - Matching mcs objects.
# 2024-12-11 16:11:47,542 - thuner.match.match - INFO - No previous mask, or no objects in previous mask.
# 2024-12-11 16:11:47,615 - thuner.track - INFO - Processing 2005-11-13T18:10:23.
# 2024-12-11 16:11:47,618 - thuner.data.aura - INFO - Updating cpol dataset for 2005-11-13T18:10:23.
# 2024-12-11 16:11:47,619 - thuner.data.aura - INFO - Converting cpol data from twp10cpolgrid150.b2.20051113.181000.nc
# 2024-12-11 16:11:48,159 - thuner.data.era5 - INFO - Updating era5_pl dataset for 2005-11-13T18:00:08.
# 2024-12-11 16:11:48,160 - thuner.data.era5 - INFO - Subsetting era5_pl data.
# 2024-12-11 16:11:50,578 - thuner.data.era5 - INFO - Updating era5_sl dataset for 2005-11-13T18:00:08.
# 2024-12-11 16:11:50,579 - thuner.data.era5 - INFO - Subsetting era5_sl data.
# 2024-12-11 16:11:50,776 - thuner.track - INFO - Processing hierarchy level 0.
# 2024-12-11 16:11:50,777 - thuner.track - INFO - Tracking convective.
# 2024-12-11 16:11:50,830 - thuner.attribute.attribute - INFO - Recording object attributes.
# 2024-12-11 16:11:50,831 - thuner.track - INFO - Tracking middle.
# 2024-12-11 16:11:50,841 - thuner.attribute.attribute - INFO - Recording object attributes.
# 2024-12-11 16:11:50,843 - thuner.track - INFO - Tracking anvil.
# 2024-12-11 16:11:50,853 - thuner.attribute.attribute - INFO - Recording object attributes.
# 2024-12-11 16:11:50,855 - thuner.track - INFO - Processing hierarchy level 1.
# 2024-12-11 16:11:50,857 - thuner.track - INFO - Tracking mcs.
# 2024-12-11 16:11:50,865 - thuner.write.mask - INFO - Writing mcs masks to /home/ewan/THUNER_output/runs/cpol/cpol_demo_geographic/masks/mcs.zarr.
# 2024-12-11 16:11:50,994 - thuner.match.match - INFO - Matching mcs objects.
# 2024-12-11 16:11:51,023 - thuner.match.match - INFO - New matchable objects. Initializing object record.
# 2024-12-11 16:11:51,030 - thuner.attribute.attribute - INFO - Recording object attributes.
# 2024-12-11 16:11:51,233 - thuner.track - INFO - Processing 2005-11-13T18:20:09.
# 2024-12-11 16:11:51,235 - thuner.data.aura - INFO - Updating cpol dataset for 2005-11-13T18:20:09.
# 2024-12-11 16:11:51,237 - thuner.data.aura - INFO - Converting cpol data from twp10cpolgrid150.b2.20051113.182000.nc
# 2024-12-11 16:11:51,848 - thuner.track - INFO - Processing hierarchy level 0.
# 2024-12-11 16:11:51,849 - thuner.track - INFO - Tracking convective.
# 2024-12-11 16:11:51,885 - thuner.attribute.attribute - INFO - Recording object attributes.
# 2024-12-11 16:11:51,887 - thuner.track - INFO - Tracking middle.
# 2024-12-11 16:11:51,893 - thuner.attribute.attribute - INFO - Recording object attributes.
# 2024-12-11 16:11:51,894 - thuner.track - INFO - Tracking anvil.
# 2024-12-11 16:11:51,899 - thuner.attribute.attribute - INFO - Recording object attributes.
# 2024-12-11 16:11:51,901 - thuner.track - INFO - Processing hierarchy level 1.
# 2024-12-11 16:11:51,902 - thuner.track - INFO - Tracking mcs.
# 2024-12-11 16:11:51,910 - thuner.write.mask - INFO - Writing mcs masks to /home/ewan/THUNER_output/runs/cpol/cpol_demo_geographic/masks/mcs.zarr.
# 2024-12-11 16:11:51,962 - thuner.match.match - INFO - Matching mcs objects.
# 2024-12-11 16:11:51,994 - thuner.match.match - INFO - Updating object record.
# 2024-12-11 16:11:52,002 - thuner.attribute.attribute - INFO - Recording object attributes.
# 2024-12-11 16:11:52,144 - thuner.track - INFO - Processing 2005-11-13T18:30:09.
# 2024-12-11 16:11:52,145 - thuner.data.aura - INFO - Updating cpol dataset for 2005-11-13T18:30:09.
# 2024-12-11 16:11:52,146 - thuner.data.aura - INFO - Converting cpol data from twp10cpolgrid150.b2.20051113.183000.nc
# 2024-12-11 16:11:52,752 - thuner.track - INFO - Processing hierarchy level 0.
# 2024-12-11 16:11:52,753 - thuner.track - INFO - Tracking convective.
# 2024-12-11 16:11:52,786 - thuner.attribute.attribute - INFO - Recording object attributes.
# 2024-12-11 16:11:52,788 - thuner.track - INFO - Tracking middle.
# 2024-12-11 16:11:52,794 - thuner.attribute.attribute - INFO - Recording object attributes.
# 2024-12-11 16:11:52,794 - thuner.track - INFO - Tracking anvil.
# 2024-12-11 16:11:52,799 - thuner.attribute.attribute - INFO - Recording object attributes.
# 2024-12-11 16:11:52,799 - thuner.track - INFO - Processing hierarchy level 1.
# 2024-12-11 16:11:52,801 - thuner.track - INFO - Tracking mcs.
# 2024-12-11 16:11:52,809 - thuner.write.mask - INFO - Writing mcs masks to /home/ewan/THUNER_output/runs/cpol/cpol_demo_geographic/masks/mcs.zarr.
# 2024-12-11 16:11:52,844 - thuner.match.match - INFO - Matching mcs objects.
# 2024-12-11 16:11:52,866 - thuner.match.match - INFO - Updating object record.
# 2024-12-11 16:11:52,873 - thuner.attribute.attribute - INFO - Recording object attributes.
# 2024-12-11 16:11:53,014 - thuner.track - INFO - Processing 2005-11-13T18:40:09.
# 2024-12-11 16:11:53,016 - thuner.data.aura - INFO - Updating cpol dataset for 2005-11-13T18:40:09.
# 2024-12-11 16:11:53,017 - thuner.data.aura - INFO - Converting cpol data from twp10cpolgrid150.b2.20051113.184000.nc
# 2024-12-11 16:11:53,564 - thuner.track - INFO - Processing hierarchy level 0.
# 2024-12-11 16:11:53,565 - thuner.track - INFO - Tracking convective.
# 2024-12-11 16:11:53,608 - thuner.attribute.attribute - INFO - Recording object attributes.
# 2024-12-11 16:11:53,609 - thuner.track - INFO - Tracking middle.
# 2024-12-11 16:11:53,613 - thuner.attribute.attribute - INFO - Recording object attributes.
# 2024-12-11 16:11:53,614 - thuner.track - INFO - Tracking anvil.
# 2024-12-11 16:11:53,622 - thuner.attribute.attribute - INFO - Recording object attributes.
# 2024-12-11 16:11:53,623 - thuner.track - INFO - Processing hierarchy level 1.
# 2024-12-11 16:11:53,623 - thuner.track - INFO - Tracking mcs.
# 2024-12-11 16:11:53,630 - thuner.write.mask - INFO - Writing mcs masks to /home/ewan/THUNER_output/runs/cpol/cpol_demo_geographic/masks/mcs.zarr.
# 2024-12-11 16:11:53,669 - thuner.match.match - INFO - Matching mcs objects.
# 2024-12-11 16:11:53,692 - thuner.match.match - INFO - Updating object record.
# 2024-12-11 16:11:53,698 - thuner.attribute.attribute - INFO - Recording object attributes.
# 2024-12-11 16:11:53,847 - thuner.track - INFO - Processing 2005-11-13T18:50:08.
# 2024-12-11 16:11:53,848 - thuner.data.aura - INFO - Updating cpol dataset for 2005-11-13T18:50:08.
# 2024-12-11 16:11:53,849 - thuner.data.aura - INFO - Converting cpol data from twp10cpolgrid150.b2.20051113.185000.nc
# 2024-12-11 16:11:54,375 - thuner.track - INFO - Processing hierarchy level 0.
# 2024-12-11 16:11:54,376 - thuner.track - INFO - Tracking convective.
# 2024-12-11 16:11:54,410 - thuner.attribute.attribute - INFO - Recording object attributes.
# 2024-12-11 16:11:54,411 - thuner.track - INFO - Tracking middle.
# 2024-12-11 16:11:54,415 - thuner.attribute.attribute - INFO - Recording object attributes.
# 2024-12-11 16:11:54,416 - thuner.track - INFO - Tracking anvil.
# 2024-12-11 16:11:54,425 - thuner.attribute.attribute - INFO - Recording object attributes.
# 2024-12-11 16:11:54,426 - thuner.track - INFO - Processing hierarchy level 1.
# 2024-12-11 16:11:54,427 - thuner.track - INFO - Tracking mcs.
# 2024-12-11 16:11:54,432 - thuner.write.mask - INFO - Writing mcs masks to /home/ewan/THUNER_output/runs/cpol/cpol_demo_geographic/masks/mcs.zarr.
# 2024-12-11 16:11:54,479 - thuner.match.match - INFO - Matching mcs objects.
# 2024-12-11 16:11:54,505 - thuner.match.match - INFO - Updating object record.
# 2024-12-11 16:11:54,511 - thuner.attribute.attribute - INFO - Recording object attributes.
# 2024-12-11 16:11:54,662 - thuner.track - INFO - Processing 2005-11-13T19:00:08.
# 2024-12-11 16:11:54,663 - thuner.data.aura - INFO - Updating cpol dataset for 2005-11-13T19:00:08.
# 2024-12-11 16:11:54,664 - thuner.data.aura - INFO - Converting cpol data from twp10cpolgrid150.b2.20051113.190000.nc
# 2024-12-11 16:11:55,224 - thuner.write.filepath - INFO - Writing cpol filepaths from 2005-11-13T18:00:00 to 2005-11-13T19:00:00, inclusive and non-inclusive, respectively.
# 2024-12-11 16:11:55,241 - thuner.track - INFO - Processing hierarchy level 0.
# 2024-12-11 16:11:55,242 - thuner.track - INFO - Tracking convective.
# 2024-12-11 16:11:55,243 - thuner.write.attribute - INFO - Writing convective attributes from 2005-11-13T18:00:00 to 2005-11-13T19:00:00, inclusive and non-inclusive, respectively.
# 2024-12-11 16:11:55,289 - thuner.attribute.attribute - INFO - Recording object attributes.
# 2024-12-11 16:11:55,290 - thuner.track - INFO - Tracking middle.
# 2024-12-11 16:11:55,291 - thuner.write.attribute - INFO - Writing middle attributes from 2005-11-13T18:00:00 to 2005-11-13T19:00:00, inclusive and non-inclusive, respectively.
# 2024-12-11 16:11:55,296 - thuner.attribute.attribute - INFO - Recording object attributes.
# 2024-12-11 16:11:55,297 - thuner.track - INFO - Tracking anvil.
# 2024-12-11 16:11:55,298 - thuner.write.attribute - INFO - Writing anvil attributes from 2005-11-13T18:00:00 to 2005-11-13T19:00:00, inclusive and non-inclusive, respectively.
# 2024-12-11 16:11:55,307 - thuner.attribute.attribute - INFO - Recording object attributes.
# 2024-12-11 16:11:55,308 - thuner.track - INFO - Processing hierarchy level 1.
# 2024-12-11 16:11:55,309 - thuner.track - INFO - Tracking mcs.
# 2024-12-11 16:11:55,313 - thuner.write.mask - INFO - Writing mcs masks to /home/ewan/THUNER_output/runs/cpol/cpol_demo_geographic/masks/mcs.zarr.
# 2024-12-11 16:11:55,335 - thuner.write.attribute - INFO - Writing mcs attributes from 2005-11-13T18:00:00 to 2005-11-13T19:00:00, inclusive and non-inclusive, respectively.
# 2024-12-11 16:11:55,444 - thuner.match.match - INFO - Matching mcs objects.
# 2024-12-11 16:11:55,465 - thuner.match.match - INFO - Updating object record.
# 2024-12-11 16:11:55,472 - thuner.attribute.attribute - INFO - Recording object attributes.
# 2024-12-11 16:11:55,610 - thuner.track - INFO - Processing 2005-11-13T19:10:23.
# 2024-12-11 16:11:55,611 - thuner.data.aura - INFO - Updating cpol dataset for 2005-11-13T19:10:23.
# 2024-12-11 16:11:55,612 - thuner.data.aura - INFO - Converting cpol data from twp10cpolgrid150.b2.20051113.191000.nc
# 2024-12-11 16:11:56,132 - thuner.track - INFO - Processing hierarchy level 0.
# 2024-12-11 16:11:56,133 - thuner.track - INFO - Tracking convective.
# 2024-12-11 16:11:56,182 - thuner.attribute.attribute - INFO - Recording object attributes.
# 2024-12-11 16:11:56,182 - thuner.track - INFO - Tracking middle.
# 2024-12-11 16:11:56,192 - thuner.attribute.attribute - INFO - Recording object attributes.
# 2024-12-11 16:11:56,193 - thuner.track - INFO - Tracking anvil.
# 2024-12-11 16:11:56,198 - thuner.attribute.attribute - INFO - Recording object attributes.
# 2024-12-11 16:11:56,199 - thuner.track - INFO - Processing hierarchy level 1.
# 2024-12-11 16:11:56,199 - thuner.track - INFO - Tracking mcs.
# 2024-12-11 16:11:56,207 - thuner.write.mask - INFO - Writing mcs masks to /home/ewan/THUNER_output/runs/cpol/cpol_demo_geographic/masks/mcs.zarr.
# 2024-12-11 16:11:56,244 - thuner.match.match - INFO - Matching mcs objects.
# 2024-12-11 16:11:56,263 - thuner.match.match - INFO - Updating object record.
# 2024-12-11 16:11:56,269 - thuner.attribute.attribute - INFO - Recording object attributes.
# 2024-12-11 16:11:56,399 - thuner.track - INFO - Processing 2005-11-13T19:20:09.
# 2024-12-11 16:11:56,402 - thuner.data.aura - INFO - Updating cpol dataset for 2005-11-13T19:20:09.
# 2024-12-11 16:11:56,404 - thuner.data.aura - INFO - Converting cpol data from twp10cpolgrid150.b2.20051113.192000.nc
# 2024-12-11 16:11:56,906 - thuner.track - INFO - Processing hierarchy level 0.
# 2024-12-11 16:11:56,907 - thuner.track - INFO - Tracking convective.
# 2024-12-11 16:11:56,947 - thuner.attribute.attribute - INFO - Recording object attributes.
# 2024-12-11 16:11:56,947 - thuner.track - INFO - Tracking middle.
# 2024-12-11 16:11:56,955 - thuner.attribute.attribute - INFO - Recording object attributes.
# 2024-12-11 16:11:56,956 - thuner.track - INFO - Tracking anvil.
# 2024-12-11 16:11:56,960 - thuner.attribute.attribute - INFO - Recording object attributes.
# 2024-12-11 16:11:56,961 - thuner.track - INFO - Processing hierarchy level 1.
# 2024-12-11 16:11:56,962 - thuner.track - INFO - Tracking mcs.
# 2024-12-11 16:11:56,965 - thuner.write.mask - INFO - Writing mcs masks to /home/ewan/THUNER_output/runs/cpol/cpol_demo_geographic/masks/mcs.zarr.
# 2024-12-11 16:11:57,002 - thuner.match.match - INFO - Matching mcs objects.
# 2024-12-11 16:11:57,027 - thuner.match.match - INFO - Updating object record.
# 2024-12-11 16:11:57,033 - thuner.attribute.attribute - INFO - Recording object attributes.
# 2024-12-11 16:11:57,172 - thuner.track - INFO - Processing 2005-11-13T19:30:09.
# 2024-12-11 16:11:57,173 - thuner.data.aura - INFO - Updating cpol dataset for 2005-11-13T19:30:09.
# 2024-12-11 16:11:57,174 - thuner.data.aura - INFO - Converting cpol data from twp10cpolgrid150.b2.20051113.193000.nc
# 2024-12-11 16:11:57,676 - thuner.track - INFO - Processing hierarchy level 0.
# 2024-12-11 16:11:57,677 - thuner.track - INFO - Tracking convective.
# 2024-12-11 16:11:57,714 - thuner.attribute.attribute - INFO - Recording object attributes.
# 2024-12-11 16:11:57,714 - thuner.track - INFO - Tracking middle.
# 2024-12-11 16:11:57,722 - thuner.attribute.attribute - INFO - Recording object attributes.
# 2024-12-11 16:11:57,723 - thuner.track - INFO - Tracking anvil.
# 2024-12-11 16:11:57,729 - thuner.attribute.attribute - INFO - Recording object attributes.
# 2024-12-11 16:11:57,730 - thuner.track - INFO - Processing hierarchy level 1.
# 2024-12-11 16:11:57,731 - thuner.track - INFO - Tracking mcs.
# 2024-12-11 16:11:57,735 - thuner.write.mask - INFO - Writing mcs masks to /home/ewan/THUNER_output/runs/cpol/cpol_demo_geographic/masks/mcs.zarr.
# 2024-12-11 16:11:57,773 - thuner.match.match - INFO - Matching mcs objects.
# 2024-12-11 16:11:57,792 - thuner.match.match - INFO - Updating object record.
# 2024-12-11 16:11:57,797 - thuner.attribute.attribute - INFO - Recording object attributes.
# 2024-12-11 16:11:57,948 - thuner.track - INFO - Processing 2005-11-13T19:40:08.
# 2024-12-11 16:11:57,949 - thuner.data.aura - INFO - Updating cpol dataset for 2005-11-13T19:40:08.
# 2024-12-11 16:11:57,953 - thuner.data.aura - INFO - Converting cpol data from twp10cpolgrid150.b2.20051113.194000.nc
# 2024-12-11 16:11:58,608 - thuner.track - INFO - Processing hierarchy level 0.
# 2024-12-11 16:11:58,609 - thuner.track - INFO - Tracking convective.
# 2024-12-11 16:11:58,693 - thuner.attribute.attribute - INFO - Recording object attributes.
# 2024-12-11 16:11:58,694 - thuner.track - INFO - Tracking middle.
# 2024-12-11 16:11:58,699 - thuner.attribute.attribute - INFO - Recording object attributes.
# 2024-12-11 16:11:58,700 - thuner.track - INFO - Tracking anvil.
# 2024-12-11 16:11:58,711 - thuner.attribute.attribute - INFO - Recording object attributes.
# 2024-12-11 16:11:58,712 - thuner.track - INFO - Processing hierarchy level 1.
# 2024-12-11 16:11:58,713 - thuner.track - INFO - Tracking mcs.
# 2024-12-11 16:11:58,720 - thuner.write.mask - INFO - Writing mcs masks to /home/ewan/THUNER_output/runs/cpol/cpol_demo_geographic/masks/mcs.zarr.
# 2024-12-11 16:11:58,761 - thuner.match.match - INFO - Matching mcs objects.
# 2024-12-11 16:11:58,786 - thuner.match.match - INFO - Updating object record.
# 2024-12-11 16:11:58,793 - thuner.attribute.attribute - INFO - Recording object attributes.
# 2024-12-11 16:11:58,949 - thuner.track - INFO - Processing 2005-11-13T19:50:08.
# 2024-12-11 16:11:58,953 - thuner.data.aura - INFO - Updating cpol dataset for 2005-11-13T19:50:08.
# 2024-12-11 16:11:58,955 - thuner.data.aura - INFO - Converting cpol data from twp10cpolgrid150.b2.20051113.195000.nc
# 2024-12-11 16:11:59,568 - thuner.track - INFO - Processing hierarchy level 0.
# 2024-12-11 16:11:59,570 - thuner.track - INFO - Tracking convective.
# 2024-12-11 16:11:59,620 - thuner.attribute.attribute - INFO - Recording object attributes.
# 2024-12-11 16:11:59,622 - thuner.track - INFO - Tracking middle.
# 2024-12-11 16:11:59,627 - thuner.attribute.attribute - INFO - Recording object attributes.
# 2024-12-11 16:11:59,628 - thuner.track - INFO - Tracking anvil.
# 2024-12-11 16:11:59,634 - thuner.attribute.attribute - INFO - Recording object attributes.
# 2024-12-11 16:11:59,636 - thuner.track - INFO - Processing hierarchy level 1.
# 2024-12-11 16:11:59,639 - thuner.track - INFO - Tracking mcs.
# 2024-12-11 16:11:59,647 - thuner.write.mask - INFO - Writing mcs masks to /home/ewan/THUNER_output/runs/cpol/cpol_demo_geographic/masks/mcs.zarr.
# 2024-12-11 16:11:59,702 - thuner.match.match - INFO - Matching mcs objects.
# 2024-12-11 16:11:59,732 - thuner.match.match - INFO - Updating object record.
# 2024-12-11 16:11:59,742 - thuner.attribute.attribute - INFO - Recording object attributes.
# 2024-12-11 16:11:59,923 - thuner.track - INFO - Processing 2005-11-13T20:00:08.
# 2024-12-11 16:11:59,924 - thuner.data.aura - INFO - Updating cpol dataset for 2005-11-13T20:00:08.
# 2024-12-11 16:11:59,925 - thuner.data.aura - INFO - Converting cpol data from twp10cpolgrid150.b2.20051113.200000.nc
# 2024-12-11 16:12:00,564 - thuner.write.filepath - INFO - Writing cpol filepaths from 2005-11-13T19:00:00 to 2005-11-13T20:00:00, inclusive and non-inclusive, respectively.
# 2024-12-11 16:12:00,571 - thuner.track - INFO - Processing hierarchy level 0.
# 2024-12-11 16:12:00,573 - thuner.track - INFO - Tracking convective.
# 2024-12-11 16:12:00,575 - thuner.write.attribute - INFO - Writing convective attributes from 2005-11-13T19:00:08 to 2005-11-13T20:00:08, inclusive and non-inclusive, respectively.
# 2024-12-11 16:12:00,624 - thuner.attribute.attribute - INFO - Recording object attributes.
# 2024-12-11 16:12:00,625 - thuner.track - INFO - Tracking middle.
# 2024-12-11 16:12:00,627 - thuner.write.attribute - INFO - Writing middle attributes from 2005-11-13T19:00:08 to 2005-11-13T20:00:08, inclusive and non-inclusive, respectively.
# 2024-12-11 16:12:00,633 - thuner.attribute.attribute - INFO - Recording object attributes.
# 2024-12-11 16:12:00,635 - thuner.track - INFO - Tracking anvil.
# 2024-12-11 16:12:00,638 - thuner.write.attribute - INFO - Writing anvil attributes from 2005-11-13T19:00:08 to 2005-11-13T20:00:08, inclusive and non-inclusive, respectively.
# 2024-12-11 16:12:00,643 - thuner.attribute.attribute - INFO - Recording object attributes.
# 2024-12-11 16:12:00,644 - thuner.track - INFO - Processing hierarchy level 1.
# 2024-12-11 16:12:00,645 - thuner.track - INFO - Tracking mcs.
# 2024-12-11 16:12:00,653 - thuner.write.mask - INFO - Writing mcs masks to /home/ewan/THUNER_output/runs/cpol/cpol_demo_geographic/masks/mcs.zarr.
# 2024-12-11 16:12:00,677 - thuner.write.attribute - INFO - Writing mcs attributes from 2005-11-13T19:00:08 to 2005-11-13T20:00:08, inclusive and non-inclusive, respectively.
# 2024-12-11 16:12:00,777 - thuner.match.match - INFO - Matching mcs objects.
# 2024-12-11 16:12:00,797 - thuner.match.match - INFO - Updating object record.
# 2024-12-11 16:12:00,804 - thuner.attribute.attribute - INFO - Recording object attributes.
# 2024-12-11 16:12:00,883 - thuner.write.attribute - INFO - Writing convective attributes from 2005-11-13T20:00:08 to 2005-11-13T21:00:08, inclusive and non-inclusive, respectively.
# 2024-12-11 16:12:00,887 - thuner.write.attribute - INFO - Writing middle attributes from 2005-11-13T20:00:08 to 2005-11-13T21:00:08, inclusive and non-inclusive, respectively.
# 2024-12-11 16:12:00,889 - thuner.write.attribute - INFO - Writing anvil attributes from 2005-11-13T20:00:08 to 2005-11-13T21:00:08, inclusive and non-inclusive, respectively.
# 2024-12-11 16:12:00,891 - thuner.write.attribute - INFO - Writing mcs attributes from 2005-11-13T20:00:08 to 2005-11-13T21:00:08, inclusive and non-inclusive, respectively.
# 2024-12-11 16:12:00,973 - thuner.write.filepath - INFO - Writing cpol filepaths from 2005-11-13T20:00:00 to 2005-11-13T21:00:00, inclusive and non-inclusive, respectively.
# 2024-12-11 16:12:00,976 - thuner.write.attribute - INFO - Aggregating attribute files.
# 2024-12-11 16:12:01,326 - thuner.write.filepath - INFO - Aggregating filepath records.
# /home/ewan/Documents/THUNER/thuner/write/attribute.py:194: FutureWarning: The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#   df = pd.concat(df_list, sort=False)

# %% [markdown]
# # Cartesian Coordinates

# %%
output_directory = base_local / "runs/cpol/cpol_demo_cartesian"
options_directory = output_directory / "options"
options_directory.mkdir(parents=True, exist_ok=True)

if output_directory.exists():
    shutil.rmtree(output_directory)

# grid_options = grid.create_options(name="cartesian", regrid=False, altitude=altitude)
# grid.check_options(grid_options)
# grid.save_grid_options(grid_options, options_directory)

grid_options = grid.GridOptions(name="cartesian", regrid=False)
grid_options.to_yaml(options_directory / "grid.yml")
data_options.to_yaml(options_directory / "data.yml")
track_options.to_yaml(options_directory / "track.yml")

# visualize.option.save_display_options(visualize_options, options_directory)

times = data.utils.generate_times(data_options.dataset_by_name("cpol"))
tracks = track.simultaneous_track(
    times,
    data_options,
    grid_options,
    track_options,
    visualize_options,
    output_directory=output_directory,
)

# %% [markdown]
# # Analysis

# %%
analysis_options = analyze.mcs.AnalysisOptions()
analysis_options.to_yaml(options_directory / "analysis.yml")
# utils.save_options(analysis_options, filename="analysis", options_directory=output_directory / "options")
analyze.mcs.process_velocities(output_directory)
analyze.mcs.quality_control(output_directory, analysis_options)
analyze.mcs.classify_all(output_directory, analysis_options)
# Out:
# 2024-12-11 16:13:31,096 - thuner.grid - WARNING - shape not specified. Will attempt to infer from input.
# 2024-12-11 16:13:31,269 - thuner.grid - WARNING - shape not specified. Will attempt to infer from input.
#                                  stratiform_offset inflow  \
# time                universal_id
# 2005-11-13 18:00:08 1                     trailing  front
# 2005-11-13 18:10:23 1                     trailing   left
# 2005-11-13 18:20:09 1                     trailing   left
# 2005-11-13 18:30:09 1                     trailing   left
# 2005-11-13 18:40:09 1                     trailing   left
# 2005-11-13 18:50:08 1                     trailing   left
# 2005-11-13 19:00:08 1                     trailing   left
# 2005-11-13 19:10:23 1                     trailing   left
# 2005-11-13 19:20:09 1                     trailing   left
# 2005-11-13 19:30:09 1                     trailing   left
# 2005-11-13 19:40:08 1                     trailing   left
# 2005-11-13 19:50:08 1                     trailing   left
#
#                                  relative_stratiform_offset      tilt  \
# time                universal_id
# 2005-11-13 18:00:08 1                              trailing  up-shear
# 2005-11-13 18:10:23 1                                  left  up-shear
# 2005-11-13 18:20:09 1                                  left  up-shear
# 2005-11-13 18:30:09 1                                  left  up-shear
# 2005-11-13 18:40:09 1                                  left  up-shear
# 2005-11-13 18:50:08 1                                  left  up-shear
# 2005-11-13 19:00:08 1                                  left  up-shear
# 2005-11-13 19:10:23 1                                  left  up-shear
# 2005-11-13 19:20:09 1                                  left  up-shear
# 2005-11-13 19:30:09 1                                  left  up-shear
# 2005-11-13 19:40:08 1                                  left  up-shear
# 2005-11-13 19:50:08 1                                  left  up-shear
#
#                                           propagation
# time                universal_id
# 2005-11-13 18:00:08 1                      down-shear
# 2005-11-13 18:10:23 1             shear-perpendicular
# 2005-11-13 18:20:09 1             shear-perpendicular
# 2005-11-13 18:30:09 1             shear-perpendicular
# 2005-11-13 18:40:09 1             shear-perpendicular
# 2005-11-13 18:50:08 1             shear-perpendicular
# 2005-11-13 19:00:08 1             shear-perpendicular
# 2005-11-13 19:10:23 1             shear-perpendicular
# 2005-11-13 19:20:09 1             shear-perpendicular
# 2005-11-13 19:30:09 1                        up-shear
# 2005-11-13 19:40:08 1                        up-shear
# 2005-11-13 19:50:08 1                        up-shear

# %%
figure_options = visualize.option.horizontal_attribute_options(
    "cpol_20051113", style="presentation", attributes=["velocity", "offset"]
)
start_time = np.datetime64("2005-11-13T18:00")
end_time = np.datetime64("2005-11-13T19:50")
visualize.attribute.mcs_series(output_directory, start_time, end_time, figure_options, parallel_figure=True, by_date=False)
# Out:
# 2024-12-11 16:13:33,185 - thuner.grid - WARNING - shape not specified. Will attempt to infer from input.
# 2024-12-11 16:13:33,397 - thuner.visualize.attribute - INFO - Visualizing MCS at time 2005-11-13T18:00:08.000000000.
# 2024-12-11 16:13:33,400 - thuner.data.aura - INFO - Converting cpol data from twp10cpolgrid150.b2.20051113.180000.nc
# 2024-12-11 16:13:33,469 - thuner.data.aura - INFO - Creating new geographic grid with spacing 0.025 m, 0.025 m.
# 2024-12-11 16:13:33,990 - thuner.grid - WARNING - shape not specified. Will attempt to infer from input.
# 2024-12-11 16:13:34,464 - thuner.visualize.attribute - INFO - Saving cpol_20051113 figure for 2005-11-13T18:00:08.000000000.
# ## You are using the Python ARM Radar Toolkit (Py-ART), an open source
# ## library for working with weather radar data. Py-ART is partly
# ## supported by the U.S. Department of Energy as part of the Atmospheric
# ## Radiation Measurement (ARM) Climate Research Facility, an Office of
# ## Science user facility.
# ##
# ## If you use this software to prepare a publication, please cite:
# ##
# ##     JJ Helmus and SM Collis, JORS 2016, doi: 10.5334/jors.119
#
#
# ## You are using the Python ARM Radar Toolkit (Py-ART), an open source
# ## library for working with weather radar data. Py-ART is partly
# ## supported by the U.S. Department of Energy as part of the Atmospheric
# ## Radiation Measurement (ARM) Climate Research Facility, an Office of
# ## Science user facility.
# ##
# ## If you use this software to prepare a publication, please cite:
# ##
# ##     JJ Helmus and SM Collis, JORS 2016, doi: 10.5334/jors.119
#
#
# ## You are using the Python ARM Radar Toolkit (Py-ART), an open source
# ## library for working with weather radar data. Py-ART is partly
# ## supported by the U.S. Department of Energy as part of the Atmospheric
# ## Radiation Measurement (ARM) Climate Research Facility, an Office of
# ## Science user facility.
# ##
# ## If you use this software to prepare a publication, please cite:
# ##
# ##     JJ Helmus and SM Collis, JORS 2016, doi: 10.5334/jors.119
#
#
# ## You are using the Python ARM Radar Toolkit (Py-ART), an open source
# ## library for working with weather radar data. Py-ART is partly
# ## supported by the U.S. Department of Energy as part of the Atmospheric
# ## Radiation Measurement (ARM) Climate Research Facility, an Office of
# ## Science user facility.
# ##
# ## If you use this software to prepare a publication, please cite:
# ##
# ##     JJ Helmus and SM Collis, JORS 2016, doi: 10.5334/jors.119
#
#
# ## You are using the Python ARM Radar Toolkit (Py-ART), an open source
# ## library for working with weather radar data. Py-ART is partly
# ## supported by the U.S. Department of Energy as part of the Atmospheric
# ## Radiation Measurement (ARM) Climate Research Facility, an Office of
# ## Science user facility.
# ##
# ## If you use this software to prepare a publication, please cite:
# ##
# ##     JJ Helmus and SM Collis, JORS 2016, doi: 10.5334/jors.119
#
#
# ## You are using the Python ARM Radar Toolkit (Py-ART), an open source
# ## library for working with weather radar data. Py-ART is partly
# ## supported by the U.S. Department of Energy as part of the Atmospheric
# ## Radiation Measurement (ARM) Climate Research Facility, an Office of
# ## Science user facility.
# ##
# ## If you use this software to prepare a publication, please cite:
# ##
# ##     JJ Helmus and SM Collis, JORS 2016, doi: 10.5334/jors.119
# 2024-12-11 16:13:43,147 - thuner.visualize.attribute - INFO - Visualizing MCS at time 2005-11-13T18:10:23.000000000.
# 2024-12-11 16:13:43,152 - thuner.data.aura - INFO - Converting cpol data from twp10cpolgrid150.b2.20051113.181000.nc
# 2024-12-11 16:13:43,515 - thuner.visualize.attribute - INFO - Visualizing MCS at time 2005-11-13T18:20:09.000000000.
# 2024-12-11 16:13:43,520 - thuner.data.aura - INFO - Converting cpol data from twp10cpolgrid150.b2.20051113.182000.nc
# 2024-12-11 16:13:44,091 - thuner.visualize.attribute - INFO - Visualizing MCS at time 2005-11-13T18:30:09.000000000.
# 2024-12-11 16:13:44,093 - thuner.data.aura - INFO - Converting cpol data from twp10cpolgrid150.b2.20051113.183000.nc
# 2024-12-11 16:13:44,928 - thuner.visualize.attribute - INFO - Visualizing MCS at time 2005-11-13T18:40:09.000000000.
# 2024-12-11 16:13:44,931 - thuner.data.aura - INFO - Converting cpol data from twp10cpolgrid150.b2.20051113.184000.nc
# 2024-12-11 16:13:46,999 - thuner.visualize.attribute - INFO - Visualizing MCS at time 2005-11-13T18:50:08.000000000.
# 2024-12-11 16:13:47,008 - thuner.data.aura - INFO - Converting cpol data from twp10cpolgrid150.b2.20051113.185000.nc
# 2024-12-11 16:13:48,663 - thuner.grid - WARNING - shape not specified. Will attempt to infer from input.
# 2024-12-11 16:13:48,712 - thuner.grid - WARNING - shape not specified. Will attempt to infer from input.
# 2024-12-11 16:13:48,728 - thuner.grid - WARNING - shape not specified. Will attempt to infer from input.
# 2024-12-11 16:13:48,981 - thuner.visualize.attribute - INFO - Visualizing MCS at time 2005-11-13T19:00:08.000000000.
# 2024-12-11 16:13:48,987 - thuner.data.aura - INFO - Converting cpol data from twp10cpolgrid150.b2.20051113.190000.nc
# 2024-12-11 16:13:49,169 - thuner.visualize.attribute - INFO - Saving cpol_20051113 figure for 2005-11-13T18:10:23.000000000.
# 2024-12-11 16:13:49,179 - thuner.visualize.attribute - INFO - Saving cpol_20051113 figure for 2005-11-13T18:20:09.000000000.
# 2024-12-11 16:13:49,303 - thuner.visualize.attribute - INFO - Saving cpol_20051113 figure for 2005-11-13T18:30:09.000000000.
# 2024-12-11 16:13:50,385 - thuner.grid - WARNING - shape not specified. Will attempt to infer from input.
# 2024-12-11 16:13:50,989 - thuner.visualize.attribute - INFO - Saving cpol_20051113 figure for 2005-11-13T18:40:09.000000000.
# 2024-12-11 16:13:52,181 - thuner.visualize.attribute - INFO - Visualizing MCS at time 2005-11-13T19:10:23.000000000.
# 2024-12-11 16:13:52,193 - thuner.data.aura - INFO - Converting cpol data from twp10cpolgrid150.b2.20051113.191000.nc
# 2024-12-11 16:13:52,880 - thuner.visualize.attribute - INFO - Visualizing MCS at time 2005-11-13T19:20:09.000000000.
# 2024-12-11 16:13:52,883 - thuner.data.aura - INFO - Converting cpol data from twp10cpolgrid150.b2.20051113.192000.nc
# 2024-12-11 16:13:53,164 - thuner.grid - WARNING - shape not specified. Will attempt to infer from input.
# 2024-12-11 16:13:53,223 - thuner.grid - WARNING - shape not specified. Will attempt to infer from input.
# 2024-12-11 16:13:53,589 - thuner.grid - WARNING - shape not specified. Will attempt to infer from input.
# 2024-12-11 16:13:53,609 - thuner.visualize.attribute - INFO - Saving cpol_20051113 figure for 2005-11-13T18:50:08.000000000.
# 2024-12-11 16:13:53,711 - thuner.visualize.attribute - INFO - Saving cpol_20051113 figure for 2005-11-13T19:10:23.000000000.
# 2024-12-11 16:13:54,040 - thuner.visualize.attribute - INFO - Saving cpol_20051113 figure for 2005-11-13T19:20:09.000000000.
# 2024-12-11 16:13:54,567 - thuner.grid - WARNING - shape not specified. Will attempt to infer from input.
# 2024-12-11 16:13:54,851 - thuner.visualize.attribute - INFO - Visualizing MCS at time 2005-11-13T19:30:09.000000000.
# 2024-12-11 16:13:54,853 - thuner.data.aura - INFO - Converting cpol data from twp10cpolgrid150.b2.20051113.193000.nc
# 2024-12-11 16:13:54,869 - thuner.visualize.attribute - INFO - Saving cpol_20051113 figure for 2005-11-13T19:00:08.000000000.
# 2024-12-11 16:13:55,298 - thuner.grid - WARNING - shape not specified. Will attempt to infer from input.
# 2024-12-11 16:13:55,538 - thuner.visualize.attribute - INFO - Saving cpol_20051113 figure for 2005-11-13T19:30:09.000000000.
# 2024-12-11 16:13:56,866 - thuner.visualize.attribute - INFO - Visualizing MCS at time 2005-11-13T19:40:08.000000000.
# 2024-12-11 16:13:56,868 - thuner.data.aura - INFO - Converting cpol data from twp10cpolgrid150.b2.20051113.194000.nc
# 2024-12-11 16:13:57,220 - thuner.grid - WARNING - shape not specified. Will attempt to infer from input.
# 2024-12-11 16:13:57,502 - thuner.visualize.attribute - INFO - Saving cpol_20051113 figure for 2005-11-13T19:40:08.000000000.
# [WARNING] yaksa: 10 leaked handle pool objects
# [WARNING] yaksa: 10 leaked handle pool objects
# [WARNING] yaksa: 10 leaked handle pool objects
# [WARNING] yaksa: 10 leaked handle pool objects
# [WARNING] yaksa: 10 leaked handle pool objects
# [WARNING] yaksa: 10 leaked handle pool objects
# 2024-12-11 16:14:00,823 - thuner.visualize.visualize - INFO - Animating cpol_20051113 figures for mcs objects.
# 2024-12-11 16:14:00,824 - thuner.visualize.visualize - INFO - Saving animation to /home/ewan/THUNER_output/runs/cpol/cpol_demo_geographic/visualize/cpol_20051113.gif.
